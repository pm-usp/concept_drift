# %% [markdown]
# # Step-by-step demonstration

# %% [markdown]
# ## Lib Imports and configurations

# %%
# %matplotlib notebook
# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2

import sys
import os
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ruptures as rpt
from ruptures.metrics import precision_recall, meantime
import scipy.stats as ss
from itertools import islice

sys.path.append("Codes/")
import TMPD_utils
import TMPD_class

import warnings
warnings.filterwarnings("ignore")

import gc
gc.enable()

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 150)
# pd.set_option('display.float_format', lambda x: f'{x:,.3f}')
pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# ## Loading event log

# %%
# Mapping all event_logs paths
logs_path = glob.glob("Input\Real\BPI Challenge 2020/*.xes.gz")

# Showing mapped paths
print("How many logs? ", len(logs_path))
pd.DataFrame(logs_path)
# Out:
# How many logs?  5
#                                                                 0
# 0       Input\Real\BPI Challenge 2020\DomesticDeclarations.xes.gz
# 1  Input\Real\BPI Challenge 2020\InternationalDeclarations.xes.gz
# 2                  Input\Real\BPI Challenge 2020\PermitLog.xes.gz
# 3          Input\Real\BPI Challenge 2020\PrepaidTravelCost.xes.gz
# 4          Input\Real\BPI Challenge 2020\RequestForPayment.xes.gz

# %% [markdown]
# <!-- ![Alt text](../Images/Concept_drift_firstcycle_steps_eng.png "General steps") -->

# %%
# Loading first event log
log_path = logs_path[0]
print(log_path.split("\\")[-1].split(".")[0])
event_log = TMPD_utils.parse_xes(log_path)

# Save original event index
event_log = event_log.reset_index(names='original_index') 

# Renaming columns to match the expected format
event_log = event_log.rename(columns={
    'org:resource': 'resource',
    'org:role': 'role',
    'case:BudgetNumber': 'BudgetNumber',
    'case:Amount': 'Amount'
})

# Showing loaded event log
print("Total events: ", len(event_log))
print("Total cases: ", len(event_log.groupby('case:id')))
print("Total activities: ", len(event_log.groupby('concept:name')))
event_log.head(50)
# Out:
# DomesticDeclarations
# parsing log, completed traces ::   0%|          | 0/10500 [00:00<?, ?it/s]
# Total events:  56437
# Total cases:  10500
# Total activities:  17
#     original_index                       id      resource  \
# 0                0          st_step 86794_0  STAFF MEMBER
# 1                1          st_step 86793_0  STAFF MEMBER
# 2                2  dd_declaration 86791_19        SYSTEM
# 3                3  dd_declaration 86791_20        SYSTEM
# 4                4          st_step 86798_0  STAFF MEMBER
# 5                5          st_step 86799_0  STAFF MEMBER
# 6                6          st_step 86797_0  STAFF MEMBER
# 7                7  dd_declaration 86795_19        SYSTEM
# 8                8  dd_declaration 86795_20        SYSTEM
# 9                9          st_step 86804_0  STAFF MEMBER
# 10              10          st_step 86802_0  STAFF MEMBER
# 11              11          st_step 86803_0  STAFF MEMBER
# 12              12  dd_declaration 86800_19        SYSTEM
# 13              13  dd_declaration 86800_20        SYSTEM
# 14              14          st_step 86733_0  STAFF MEMBER
# 15              15          st_step 86734_0  STAFF MEMBER
# 16              16  dd_declaration 86731_19        SYSTEM
# 17              17  dd_declaration 86731_20        SYSTEM
# 18              18          st_step 86738_0  STAFF MEMBER
# 19              19          st_step 86737_0  STAFF MEMBER
# 20              20  dd_declaration 86735_19        SYSTEM
# 21              21  dd_declaration 86735_20        SYSTEM
# 22              22          st_step 86807_0  STAFF MEMBER
# 23              23          st_step 86808_0  STAFF MEMBER
# 24              24  dd_declaration 86805_19        SYSTEM
# 25              25  dd_declaration 86805_20        SYSTEM
# 26              26          st_step 86814_0  STAFF MEMBER
# 27              27          st_step 86813_0  STAFF MEMBER
# 28              28          st_step 86815_0  STAFF MEMBER
# 29              29          st_step 86812_0  STAFF MEMBER
# 30              30          st_step 86811_0  STAFF MEMBER
# 31              31  dd_declaration 86809_19        SYSTEM
# 32              32  dd_declaration 86809_20        SYSTEM
# 33              33          st_step 86819_0  STAFF MEMBER
# 34              34          st_step 86818_0  STAFF MEMBER
# 35              35  dd_declaration 86816_19        SYSTEM
# 36              36  dd_declaration 86816_20        SYSTEM
# 37              37          st_step 86719_0  STAFF MEMBER
# 38              38          st_step 86718_0  STAFF MEMBER
# 39              39  dd_declaration 86716_19        SYSTEM
# 40              40  dd_declaration 86716_20        SYSTEM
# 41              41          st_step 86728_0  STAFF MEMBER
# 42              42          st_step 86729_0  STAFF MEMBER
# 43              43          st_step 86730_0  STAFF MEMBER
# 44              44          st_step 86725_0  STAFF MEMBER
# 45              45          st_step 86726_0  STAFF MEMBER
# 46              46          st_step 86727_0  STAFF MEMBER
# 47              47          st_step 86724_0  STAFF MEMBER
# 48              48          st_step 86723_0  STAFF MEMBER
# 49              49          st_step 86722_0  STAFF MEMBER
#
#                                 concept:name            time:timestamp  \
# 0          Declaration SUBMITTED by EMPLOYEE 2017-01-09 09:49:50+00:00
# 1   Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 11:27:48+00:00
# 2                            Request Payment 2017-01-10 09:34:44+00:00
# 3                            Payment Handled 2017-01-12 17:31:22+00:00
# 4          Declaration SUBMITTED by EMPLOYEE 2017-01-09 10:26:14+00:00
# 5       Declaration APPROVED by PRE_APPROVER 2017-02-22 10:29:21+00:00
# 6   Declaration FINAL_APPROVED by SUPERVISOR 2017-02-23 08:14:45+00:00
# 7                            Request Payment 2017-03-06 14:07:25+00:00
# 8                            Payment Handled 2017-03-13 17:30:59+00:00
# 9          Declaration SUBMITTED by EMPLOYEE 2017-01-09 11:13:33+00:00
# 10      Declaration APPROVED by PRE_APPROVER 2017-02-02 18:58:50+00:00
# 11  Declaration FINAL_APPROVED by SUPERVISOR 2017-02-09 05:15:04+00:00
# 12                           Request Payment 2017-02-09 16:00:15+00:00
# 13                           Payment Handled 2017-02-13 17:32:14+00:00
# 14         Declaration SUBMITTED by EMPLOYEE 2017-01-09 11:24:20+00:00
# 15  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 11:37:23+00:00
# 16                           Request Payment 2017-01-11 14:37:18+00:00
# 17                           Payment Handled 2017-01-16 17:32:14+00:00
# 18         Declaration SUBMITTED by EMPLOYEE 2017-01-09 11:30:26+00:00
# 19  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 11:37:18+00:00
# 20                           Request Payment 2017-01-11 14:37:18+00:00
# 21                           Payment Handled 2017-01-16 17:32:14+00:00
# 22         Declaration SUBMITTED by EMPLOYEE 2017-01-09 11:40:47+00:00
# 23  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 11:41:23+00:00
# 24                           Request Payment 2017-01-25 10:31:31+00:00
# 25                           Payment Handled 2017-01-30 17:31:35+00:00
# 26         Declaration SUBMITTED by EMPLOYEE 2017-01-09 12:14:36+00:00
# 27  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 12:14:49+00:00
# 28           Declaration REJECTED by MISSING 2017-01-10 15:35:19+00:00
# 29         Declaration SUBMITTED by EMPLOYEE 2017-01-20 14:43:27+00:00
# 30  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-20 14:44:43+00:00
# 31                           Request Payment 2017-01-27 10:55:21+00:00
# 32                           Payment Handled 2017-01-30 17:31:35+00:00
# 33         Declaration SUBMITTED by EMPLOYEE 2017-01-09 14:51:44+00:00
# 34  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 14:52:05+00:00
# 35                           Request Payment 2017-01-11 09:04:31+00:00
# 36                           Payment Handled 2017-01-16 17:32:14+00:00
# 37         Declaration SUBMITTED by EMPLOYEE 2017-01-09 15:10:05+00:00
# 38  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 15:11:23+00:00
# 39                           Request Payment 2017-01-13 14:09:36+00:00
# 40                           Payment Handled 2017-01-16 17:32:14+00:00
# 41         Declaration SUBMITTED by EMPLOYEE 2017-01-09 15:57:21+00:00
# 42  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 15:57:24+00:00
# 43           Declaration REJECTED by MISSING 2017-01-10 13:08:27+00:00
# 44         Declaration SUBMITTED by EMPLOYEE 2017-01-17 16:51:42+00:00
# 45      Declaration REJECTED by PRE_APPROVER 2017-01-17 16:51:54+00:00
# 46          Declaration REJECTED by EMPLOYEE 2017-01-19 12:19:38+00:00
# 47         Declaration SUBMITTED by EMPLOYEE 2017-01-19 16:13:16+00:00
# 48      Declaration APPROVED by PRE_APPROVER 2017-01-19 16:13:46+00:00
# 49  Declaration FINAL_APPROVED by SUPERVISOR 2017-01-23 08:52:57+00:00
#
#             role            case:id  case:concept:name  BudgetNumber  \
# 0       EMPLOYEE  declaration 86791  declaration 86791  budget 86566
# 1     SUPERVISOR  declaration 86791  declaration 86791  budget 86566
# 2      UNDEFINED  declaration 86791  declaration 86791  budget 86566
# 3      UNDEFINED  declaration 86791  declaration 86791  budget 86566
# 4       EMPLOYEE  declaration 86795  declaration 86795  budget 86566
# 5   PRE_APPROVER  declaration 86795  declaration 86795  budget 86566
# 6     SUPERVISOR  declaration 86795  declaration 86795  budget 86566
# 7      UNDEFINED  declaration 86795  declaration 86795  budget 86566
# 8      UNDEFINED  declaration 86795  declaration 86795  budget 86566
# 9       EMPLOYEE  declaration 86800  declaration 86800  budget 86566
# 10  PRE_APPROVER  declaration 86800  declaration 86800  budget 86566
# 11    SUPERVISOR  declaration 86800  declaration 86800  budget 86566
# 12     UNDEFINED  declaration 86800  declaration 86800  budget 86566
# 13     UNDEFINED  declaration 86800  declaration 86800  budget 86566
# 14      EMPLOYEE  declaration 86731  declaration 86731  budget 86566
# 15    SUPERVISOR  declaration 86731  declaration 86731  budget 86566
# 16     UNDEFINED  declaration 86731  declaration 86731  budget 86566
# 17     UNDEFINED  declaration 86731  declaration 86731  budget 86566
# 18      EMPLOYEE  declaration 86735  declaration 86735  budget 86566
# 19    SUPERVISOR  declaration 86735  declaration 86735  budget 86566
# 20     UNDEFINED  declaration 86735  declaration 86735  budget 86566
# 21     UNDEFINED  declaration 86735  declaration 86735  budget 86566
# 22      EMPLOYEE  declaration 86805  declaration 86805  budget 86566
# 23    SUPERVISOR  declaration 86805  declaration 86805  budget 86566
# 24     UNDEFINED  declaration 86805  declaration 86805  budget 86566
# 25     UNDEFINED  declaration 86805  declaration 86805  budget 86566
# 26      EMPLOYEE  declaration 86809  declaration 86809  budget 86566
# 27    SUPERVISOR  declaration 86809  declaration 86809  budget 86566
# 28       MISSING  declaration 86809  declaration 86809  budget 86566
# 29      EMPLOYEE  declaration 86809  declaration 86809  budget 86566
# 30    SUPERVISOR  declaration 86809  declaration 86809  budget 86566
# 31     UNDEFINED  declaration 86809  declaration 86809  budget 86566
# 32     UNDEFINED  declaration 86809  declaration 86809  budget 86566
# 33      EMPLOYEE  declaration 86816  declaration 86816  budget 86566
# 34    SUPERVISOR  declaration 86816  declaration 86816  budget 86566
# 35     UNDEFINED  declaration 86816  declaration 86816  budget 86566
# 36     UNDEFINED  declaration 86816  declaration 86816  budget 86566
# 37      EMPLOYEE  declaration 86716  declaration 86716  budget 86566
# 38    SUPERVISOR  declaration 86716  declaration 86716  budget 86566
# 39     UNDEFINED  declaration 86716  declaration 86716  budget 86566
# 40     UNDEFINED  declaration 86716  declaration 86716  budget 86566
# 41      EMPLOYEE  declaration 86720  declaration 86720  budget 86566
# 42    SUPERVISOR  declaration 86720  declaration 86720  budget 86566
# 43       MISSING  declaration 86720  declaration 86720  budget 86566
# 44      EMPLOYEE  declaration 86720  declaration 86720  budget 86566
# 45  PRE_APPROVER  declaration 86720  declaration 86720  budget 86566
# 46      EMPLOYEE  declaration 86720  declaration 86720  budget 86566
# 47      EMPLOYEE  declaration 86720  declaration 86720  budget 86566
# 48  PRE_APPROVER  declaration 86720  declaration 86720  budget 86566
# 49    SUPERVISOR  declaration 86720  declaration 86720  budget 86566
#
#       case:DeclarationNumber   Amount
# 0   declaration number 86792  26.8512
# 1   declaration number 86792  26.8512
# 2   declaration number 86792  26.8512
# 3   declaration number 86792  26.8512
# 4   declaration number 86796 182.4642
# 5   declaration number 86796 182.4642
# 6   declaration number 86796 182.4642
# 7   declaration number 86796 182.4642
# 8   declaration number 86796 182.4642
# 9   declaration number 86801 320.6461
# 10  declaration number 86801 320.6461
# 11  declaration number 86801 320.6461
# 12  declaration number 86801 320.6461
# 13  declaration number 86801 320.6461
# 14  declaration number 86732 113.8620
# 15  declaration number 86732 113.8620
# 16  declaration number 86732 113.8620
# 17  declaration number 86732 113.8620
# 18  declaration number 86736 134.4042
# 19  declaration number 86736 134.4042
# 20  declaration number 86736 134.4042
# 21  declaration number 86736 134.4042
# 22  declaration number 86806 443.5852
# 23  declaration number 86806 443.5852
# 24  declaration number 86806 443.5852
# 25  declaration number 86806 443.5852
# 26  declaration number 86810 333.4409
# 27  declaration number 86810 333.4409
# 28  declaration number 86810 333.4409
# 29  declaration number 86810 333.4409
# 30  declaration number 86810 333.4409
# 31  declaration number 86810 333.4409
# 32  declaration number 86810 333.4409
# 33  declaration number 86817  29.9517
# 34  declaration number 86817  29.9517
# 35  declaration number 86817  29.9517
# 36  declaration number 86817  29.9517
# 37  declaration number 86717  22.7655
# 38  declaration number 86717  22.7655
# 39  declaration number 86717  22.7655
# 40  declaration number 86717  22.7655
# 41  declaration number 86721 105.6041
# 42  declaration number 86721 105.6041
# 43  declaration number 86721 105.6041
# 44  declaration number 86721 105.6041
# 45  declaration number 86721 105.6041
# 46  declaration number 86721 105.6041
# 47  declaration number 86721 105.6041
# 48  declaration number 86721 105.6041
# 49  declaration number 86721 105.6041

# %% [markdown]
# ## Step 1 - Instantiating class and setting event log

# %%
# Iniatializing the TMPD_class
TMPD_instance = TMPD_class.TMPD(scenario='offline')

# Setting the transition log
TMPD_instance.set_transition_log(event_log, case_id='case:id', activity_key='concept:name', timestamp_key='time:timestamp', timestamp_format=None, other_columns_keys=["role", "resource", "BudgetNumber", "Amount"])

# Executing the transition log
TMPD_instance.run_transition_log()

# Showing the transition log created
print(len(TMPD_instance.get_transition_log()))
TMPD_instance.get_transition_log().head()
# Out:
# 66937
#              case_id                             activity_from  \
# 0  declaration 86791                                     START
# 1  declaration 86791         Declaration_SUBMITTED_by_EMPLOYEE
# 2  declaration 86791  Declaration_FINAL_APPROVED_by_SUPERVISOR
# 3  declaration 86791                           Request_Payment
# 4  declaration 86791                           Payment_Handled
#
#              timestamp_from   role_from resource_from BudgetNumber_from  \
# 0 2017-01-09 09:49:50+00:00    EMPLOYEE  STAFF MEMBER      budget 86566
# 1 2017-01-09 09:49:50+00:00    EMPLOYEE  STAFF MEMBER      budget 86566
# 2 2017-01-09 11:27:48+00:00  SUPERVISOR  STAFF MEMBER      budget 86566
# 3 2017-01-10 09:34:44+00:00   UNDEFINED        SYSTEM      budget 86566
# 4 2017-01-12 17:31:22+00:00   UNDEFINED        SYSTEM      budget 86566
#
#    Amount_from  event_order_from                               activity_to  \
# 0      26.8512                 0         Declaration_SUBMITTED_by_EMPLOYEE
# 1      26.8512                 0  Declaration_FINAL_APPROVED_by_SUPERVISOR
# 2      26.8512                 1                           Request_Payment
# 3      26.8512                 2                           Payment_Handled
# 4      26.8512                 3                                       END
#
#                timestamp_to     role_to   resource_to BudgetNumber_to  \
# 0 2017-01-09 09:49:50+00:00    EMPLOYEE  STAFF MEMBER    budget 86566
# 1 2017-01-09 11:27:48+00:00  SUPERVISOR  STAFF MEMBER    budget 86566
# 2 2017-01-10 09:34:44+00:00   UNDEFINED        SYSTEM    budget 86566
# 3 2017-01-12 17:31:22+00:00   UNDEFINED        SYSTEM    budget 86566
# 4 2017-01-12 17:31:22+00:00   UNDEFINED        SYSTEM    budget 86566
#
#    Amount_to  event_order_to  case_order  transition_id
# 0    26.8512          0.0000           0              0
# 1    26.8512          1.0000           1              1
# 2    26.8512          2.0000           2              2
# 3    26.8512          3.0000           3              3
# 4    26.8512          3.0000           4              4

# %% [markdown]
# ## Step 2 - Setting Window Strategy

# %%
# Setting the window strategy parameters
TMPD_instance.set_windowing_strategy(window_size_mode = 'Fixed', window_size = 2000, window_ref_mode = "Sliding", overlap = True, sliding_step = 1000, continuous = True)

# Executing the window strategy indexation
TMPD_instance.run_windowing_strategy()

# Showing the windows indexes
dict(list(TMPD_instance.get_windowing_strategy().items()))
# Out:
# {0: {'start': 0, 'end': 2000},
#  1: {'start': 1000, 'end': 3000},
#  2: {'start': 2000, 'end': 4000},
#  3: {'start': 3000, 'end': 5000},
#  4: {'start': 4000, 'end': 6000},
#  5: {'start': 5000, 'end': 7000},
#  6: {'start': 6000, 'end': 8000},
#  7: {'start': 7000, 'end': 9000},
#  8: {'start': 8000, 'end': 10000},
#  9: {'start': 9000, 'end': 11000},
#  10: {'start': 10000, 'end': 12000},
#  11: {'start': 11000, 'end': 13000},
#  12: {'start': 12000, 'end': 14000},
#  13: {'start': 13000, 'end': 15000},
#  14: {'start': 14000, 'end': 16000},
#  15: {'start': 15000, 'end': 17000},
#  16: {'start': 16000, 'end': 18000},
#  17: {'start': 17000, 'end': 19000},
#  18: {'start': 18000, 'end': 20000},
#  19: {'start': 19000, 'end': 21000},
#  20: {'start': 20000, 'end': 22000},
#  21: {'start': 21000, 'end': 23000},
#  22: {'start': 22000, 'end': 24000},
#  23: {'start': 23000, 'end': 25000},
#  24: {'start': 24000, 'end': 26000},
#  25: {'start': 25000, 'end': 27000},
#  26: {'start': 26000, 'end': 28000},
#  27: {'start': 27000, 'end': 29000},
#  28: {'start': 28000, 'end': 30000},
#  29: {'start': 29000, 'end': 31000},
#  30: {'start': 30000, 'end': 32000},
#  31: {'start': 31000, 'end': 33000},
#  32: {'start': 32000, 'end': 34000},
#  33: {'start': 33000, 'end': 35000},
#  34: {'start': 34000, 'end': 36000},
#  35: {'start': 35000, 'end': 37000},
#  36: {'start': 36000, 'end': 38000},
#  37: {'start': 37000, 'end': 39000},
#  38: {'start': 38000, 'end': 40000},
#  39: {'start': 39000, 'end': 41000},
#  40: {'start': 40000, 'end': 42000},
#  41: {'start': 41000, 'end': 43000},
#  42: {'start': 42000, 'end': 44000},
#  43: {'start': 43000, 'end': 45000},
#  44: {'start': 44000, 'end': 46000},
#  45: {'start': 45000, 'end': 47000},
#  46: {'start': 46000, 'end': 48000},
#  47: {'start': 47000, 'end': 49000},
#  48: {'start': 48000, 'end': 50000},
#  49: {'start': 49000, 'end': 51000},
#  50: {'start': 50000, 'end': 52000},
#  51: {'start': 51000, 'end': 53000},
#  52: {'start': 52000, 'end': 54000},
#  53: {'start': 53000, 'end': 55000},
#  54: {'start': 54000, 'end': 56000},
#  55: {'start': 55000, 'end': 57000},
#  56: {'start': 56000, 'end': 58000},
#  57: {'start': 57000, 'end': 59000},
#  58: {'start': 58000, 'end': 60000},
#  59: {'start': 59000, 'end': 61000},
#  60: {'start': 60000, 'end': 62000},
#  61: {'start': 61000, 'end': 63000},
#  62: {'start': 62000, 'end': 64000},
#  63: {'start': 63000, 'end': 65000},
#  64: {'start': 64000, 'end': 66000}}

# %% [markdown]
# ## Step 3 - Setting Process Representation (using Transition Matrix)

# %%
# Setting the Transition Matrix (TM) process representation
TMPD_instance.set_process_representation(threshold_anomaly=0.005
                                    , control_flow_features={'frequency', 'probability', 'causality', 'parallel', 'choice', 'loop'}
                                    , time_features={('time_avg','timestamp'), ('time_std','timestamp')}
                                    , resource_features={('categorical_encoding_frequency', 'role')#, ('categorical_encoding_probability', 'role')
                                                        #  , ('categorical_unique', 'role'), ('categorical_entropy', 'role')
                                                         , ('categorical_encoding_frequency', 'resource')#, ('categorical_encoding_probability', 'resource')
                                                        # , ('categorical_unique', 'resource'), ('categorical_entropy', 'resource')
                                                         } 
                                    , data_features={('numerical_avg', 'Amount'), ('numerical_std', 'Amount')
                                                        , ('categorical_unique', 'BudgetNumber'), ('categorical_entropy', 'BudgetNumber')
                                                        # , ('categorical_encoding_frequency', 'BudgetNumber'), ('categorical_encoding_probability', 'BudgetNumber')
                                                    }
                                    )

# Executing the process_representation using all dataset just for an example
TMPD_instance.run_process_representation(TMPD_instance.transition_log)

# Showing the process representation created
TMPD_instance.get_process_representation()#.head(15)
# Out:
#                                                                                    frequency  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER           2820
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       5133
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR       2788
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR        674
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                               10038
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                928
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              1081
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION         8202
#                                          Declaration_APPROVED_by_PRE_APPROVER            685
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       1536
#                                          Declaration_REJECTED_by_ADMINISTRATION          952
# Payment_Handled                          END                                           10043
# Request_Payment                          Payment_Handled                               10037
# START                                    Declaration_SUBMITTED_by_EMPLOYEE             10365
#
#                                                                                    percentual  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER          0.0421
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0767
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0417
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0101
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                               0.1500
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE              0.0139
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE             0.0161
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION        0.1225
#                                          Declaration_APPROVED_by_PRE_APPROVER          0.0102
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0229
#                                          Declaration_REJECTED_by_ADMINISTRATION        0.0142
# Payment_Handled                          END                                           0.1500
# Request_Payment                          Payment_Handled                               0.1499
# START                                    Declaration_SUBMITTED_by_EMPLOYEE             0.1548
#
#                                                                                    probability  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER           0.3546
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       0.6454
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR       1.0000
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR       1.0000
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                1.0000
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE               1.0000
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              1.0000
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION         0.7211
#                                          Declaration_APPROVED_by_PRE_APPROVER           0.0602
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       0.1350
#                                          Declaration_REJECTED_by_ADMINISTRATION         0.0837
# Payment_Handled                          END                                            1.0000
# Request_Payment                          Payment_Handled                                1.0000
# START                                    Declaration_SUBMITTED_by_EMPLOYEE              1.0000
#
#                                                                                    causality  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR          0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR          1
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR          1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                   1
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                  1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                 1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION            0
#                                          Declaration_APPROVED_by_PRE_APPROVER              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR          0
#                                          Declaration_REJECTED_by_ADMINISTRATION            0
# Payment_Handled                          END                                               1
# Request_Payment                          Payment_Handled                                   1
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                 1
#
#                                                                                    parallel  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR         0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR         0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                  0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION           0
#                                          Declaration_APPROVED_by_PRE_APPROVER             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR         0
#                                          Declaration_REJECTED_by_ADMINISTRATION           0
# Payment_Handled                          END                                              0
# Request_Payment                          Payment_Handled                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                0
#
#                                                                                    choice  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER           1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       1
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR       0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION         1
#                                          Declaration_APPROVED_by_PRE_APPROVER           1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       1
#                                          Declaration_REJECTED_by_ADMINISTRATION         1
# Payment_Handled                          END                                            0
# Request_Payment                          Payment_Handled                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE              0
#
#                                                                                    loop  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER         0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR     0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR     0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR     0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                              0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE             1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE            1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION       0
#                                          Declaration_APPROVED_by_PRE_APPROVER         0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR     0
#                                          Declaration_REJECTED_by_ADMINISTRATION       1
# Payment_Handled                          END                                          0
# Request_Payment                          Payment_Handled                              0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE            0
#
#                                                                                    time_avg_timestamp  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER               2732.8157
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR           2738.8462
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR           4124.2916
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR           2719.3132
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                    4554.4438
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                   2942.7825
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                  7457.0927
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION             1664.3430
#                                          Declaration_APPROVED_by_PRE_APPROVER               1787.6789
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR           1365.4759
#                                          Declaration_REJECTED_by_ADMINISTRATION             8154.1001
# Payment_Handled                          END                                                   0.0000
# Request_Payment                          Payment_Handled                                    5147.4676
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     0.0000
#
#                                                                                    time_std_timestamp  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER               4505.2163
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR           4357.6735
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR           3527.9278
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR           3173.6195
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                   10341.0534
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                   3892.2871
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                 26598.9672
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION            11859.6153
#                                          Declaration_APPROVED_by_PRE_APPROVER              10774.6591
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR          10449.0865
#                                          Declaration_REJECTED_by_ADMINISTRATION            42463.2697
# Payment_Handled                          END                                                   0.0000
# Request_Payment                          Payment_Handled                                    3535.4875
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     0.0000
#
#                                                                                    categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                    2820
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                5133
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                2788
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 674
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                            0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                         928
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                       1081
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                  8202
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                     685
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                1536
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                   952
# Payment_Handled                          END                                                                                                        0
# Request_Payment                          Payment_Handled                                                                                            0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                      10365
#
#                                                                                    categorical_encoding_frequency_resource_STAFF MEMBER->SYSTEM  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                  10038
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_resource_SYSTEM->STAFF MEMBER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_resource_SYSTEM->SYSTEM  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                              0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                         0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                         0
# Payment_Handled                          END                                                                                        10043
# Request_Payment                          Payment_Handled                                                                            10037
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                              0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->ADMINISTRATION  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                       0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                   0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                   0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                   0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                            0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                           0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                          0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                     0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                       0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                   0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                     0
# Payment_Handled                          END                                                                                                        0
# Request_Payment                          Payment_Handled                                                                                            0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                          0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                  2820
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                          0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                         0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                   0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                     0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                   0
# Payment_Handled                          END                                                                                                      0
# Request_Payment                          Payment_Handled                                                                                          0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                   928
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                   0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                            5133
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                               0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                               0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                        0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                       0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                      0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                 0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                   0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                               0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                 0
# Payment_Handled                          END                                                                                                    0
# Request_Payment                          Payment_Handled                                                                                        0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                      0
#
#                                                                                    categorical_encoding_frequency_role_BUDGET OWNER->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                               0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                    0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                   0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                             0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                               0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                             0
# Payment_Handled                          END                                                                                                0
# Request_Payment                          Payment_Handled                                                                                    0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
#
#                                                                                    categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          2788
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                            8202
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                             952
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                           1081
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                         0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                         0
# Payment_Handled                          END                                                                                            0
# Request_Payment                          Payment_Handled                                                                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                          10365
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->PRE_APPROVER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                               0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                    0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                   0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                             0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                             685
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                             0
# Payment_Handled                          END                                                                                                0
# Request_Payment                          Payment_Handled                                                                                    0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                  0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                           0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                      1536
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                           0
# Payment_Handled                          END                                                                                              0
# Request_Payment                          Payment_Handled                                                                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->UNDEFINED  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                            0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                 0
# ...
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                               10038
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                            0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                            0
# Payment_Handled                          END                                                                                               0
# Request_Payment                          Payment_Handled                                                                                   0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
#
#                                                                                    categorical_encoding_frequency_role_UNDEFINED->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                            0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                 0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                               0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                          0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                            0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                          0
# Payment_Handled                          END                                                                                             0
# Request_Payment                          Payment_Handled                                                                                 0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                               0
#
#                                                                                    categorical_encoding_frequency_role_UNDEFINED->MISSING  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                              0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                         0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                         0
# Payment_Handled                          END                                                                                            0
# Request_Payment                          Payment_Handled                                                                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                              0
#
#                                                                                    categorical_encoding_frequency_role_UNDEFINED->UNDEFINED  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                  0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                           0
#                                          Declaration_APPROVED_by_PRE_APPROVER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                           0
# Payment_Handled                          END                                                                                          10043
# Request_Payment                          Payment_Handled                                                                              10037
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    numerical_avg_Amount  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                   94.3976
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR               89.6322
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR               94.4516
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR               90.9782
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                        90.2691
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                      146.1932
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                     167.4440
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                 92.0052
#                                          Declaration_APPROVED_by_PRE_APPROVER                   93.9855
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR               88.0678
#                                          Declaration_REJECTED_by_ADMINISTRATION                144.2612
# Payment_Handled                          END                                                    90.2668
# Request_Payment                          Payment_Handled                                        90.2766
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                      87.5402
#
#                                                                                    categorical_unique_BudgetNumber  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                    1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                         1
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                        1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                       1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                  1
#                                          Declaration_APPROVED_by_PRE_APPROVER                                    1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
#                                          Declaration_REJECTED_by_ADMINISTRATION                                  1
# Payment_Handled                          END                                                                     1
# Request_Payment                          Payment_Handled                                                         1
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                       1
#
#                                                                                    numerical_std_Amount  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                  148.4924
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR              148.8082
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR              148.7694
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR              152.9641
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                       146.6202
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                      266.0825
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                     276.1446
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                153.5105
#                                          Declaration_APPROVED_by_PRE_APPROVER                  163.0022
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR              140.9255
#                                          Declaration_REJECTED_by_ADMINISTRATION                264.4706
# Payment_Handled                          END                                                   146.5946
# Request_Payment                          Payment_Handled                                       146.6254
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     145.1385
#
#                                                                                    categorical_entropy_BudgetNumber
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                0.0000
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                     0.0000
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                    0.0000
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                              0.0000
#                                          Declaration_APPROVED_by_PRE_APPROVER                                0.0000
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
#                                          Declaration_REJECTED_by_ADMINISTRATION                              0.0000
# Payment_Handled                          END                                                                 0.0000
# Request_Payment                          Payment_Handled                                                     0.0000
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000

# %% [markdown]
# ## Step 4 - Setting Change Representation

# %%
# Defining the change features
change_features_strategy_dict = {
    'delta_matrix_strategy': 
        {
            ### Control Flow Perspective
            'frequency_delta' : {'process_feature':'frequency', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'probability_delta' : {'process_feature':'probability', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'causality_delta' : {'process_feature':'causality', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'parallel_delta' : {'process_feature':'parallel', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'frequency_delta_percentage' : {'process_feature':'frequency', 'method':'percentage'}
            , 'prob_freq_delta_weight' : {'process_feature':'probability', 'method':'aggregation_weight', 'agg_function' : 'sum', 'weight_feature' : 'frequency'}

            ### Time Perspective
            , 'time_avg_delta' : {'process_feature':'time_avg_timestamp', 'method':'aggregation', 'agg_function' : 'sum'}
            , 'time_std_delta' : {'process_feature':'time_std_timestamp', 'method':'aggregation', 'agg_function' : 'sum'}

            ### Resource Perspective
            # , 'role_unique_delta' : {'process_feature':'categorical_unique_role', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'role_entropy_delta' : {'process_feature':'categorical_entropy_role', 'method':'aggregation', 'agg_function' : 'sum'}
            , 'role_encoding_frequency_delta' : {'process_feature':'categorical_encoding_frequency_role', 'method':'multiple_aggregation', 'agg_function' : 'sum'}
            # , 'role_encoding_probability_delta' : {'process_feature':'categorical_encoding_probability_role', 'method':'multiple_aggregation', 'agg_function' : 'sum'}

            #  , 'resource_unique_delta' : {'process_feature':'categorical_unique_resource', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'resource_entropy_delta' : {'process_feature':'categorical_entropy_resource', 'method':'aggregation', 'agg_function' : 'sum'}
            , 'resource_encoding_frequency_delta' : {'process_feature':'categorical_encoding_frequency_resource', 'method':'multiple_aggregation', 'agg_function' : 'sum'}
            # , 'resource_encoding_probability_delta' : {'process_feature':'categorical_encoding_probability_resource', 'method':'multiple_aggregation', 'agg_function' : 'sum'}

            ### Data Perspective
            , 'amount_avg_delta' : {'process_feature':'numerical_avg_Amount', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'amount_std_delta' : {'process_feature':'numerical_std_Amount', 'method':'aggregation', 'agg_function' : 'sum'}
            , 'BudgetNumber_unique_delta' : {'process_feature':'categorical_unique_BudgetNumber', 'method':'aggregation', 'agg_function' : 'sum'}
            , 'BudgetNumber_entropy_delta' : {'process_feature':'categorical_entropy_BudgetNumber', 'method':'aggregation', 'agg_function' : 'sum'}
            # , 'BudgetNumber_encoding_frequency_delta' : {'process_feature':'categorical_encoding_frequency_BudgetNumber', 'method':'multiple_aggregation', 'agg_function' : 'sum'}
            # , 'BudgetNumber_encoding_probability_delta' : {'process_feature':'categorical_encoding_probability_BudgetNumber', 'method':'multiple_aggregation', 'agg_function' : 'sum'}
        }
    , 'statistic_test_strategy' : 
        {
            ### Control Flow Perspective
            'frequency_gtest_pvalue' : {'process_feature':'frequency', 'method':'g_test', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
            , 'frequency_cramersv' : {'process_feature':'frequency', 'method':'cramers_v', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
        }
    }

# Setting Change Representation
TMPD_instance.set_change_representation(change_features_strategy_dict)

# Executing the Change Representation using the window strategy
TMPD_instance.run_change_representation()

# Showing the Change Representation created
TMPD_instance.get_change_representation().head()
# Out:
#    start   end  reference_window_index  frequency_delta  \
# 0      0  2000                     NaN              NaN
# 1   1000  3000                  0.0000         152.0000
# 2   2000  4000                  1.0000         111.0000
# 3   3000  5000                  2.0000          39.0000
# 4   4000  6000                  3.0000         102.0000
#
#    prob_freq_delta_weight  time_avg_delta  time_std_delta  \
# 0                     NaN             NaN             NaN
# 1                 29.9189      53307.4376     103267.8298
# 2                 12.5400      53983.4429     159567.9532
# 3                 11.1914      14775.0716      46823.5652
# 4                  1.3374      49403.2208     172679.3432
#
#    role_encoding_frequency_delta  resource_encoding_frequency_delta  \
# 0                            NaN                                NaN
# 1                       608.0000                           608.0000
# 2                      1776.0000                          1776.0000
# 3                       624.0000                           624.0000
# 4                      1632.0000                          1632.0000
#
#    amount_avg_delta  BudgetNumber_unique_delta  BudgetNumber_entropy_delta  \
# 0               NaN                        NaN                         NaN
# 1          417.6570                     3.0000                      0.0000
# 2          388.8107                     1.0000                      0.0000
# 3          273.4267                     1.0000                      0.0000
# 4          109.6071                     0.0000                      0.0000
#
#    frequency_gtest_pvalue  frequency_cramersv
# 0                     NaN                 NaN
# 1                  0.0022              0.0687
# 2                  0.4897              0.0000
# 3                  0.8441              0.0000
# 4                  0.7785              0.0000

# %% [markdown]
# ## Step 5 - Setting Detection Task

# %%
# Defining detection strategies
detection_task_strategy_dict = {
    'time_series_strategy': 
    {
        ### Control Flow Perspective
        'cpd_frequency_delta' : {'change_features':['frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        , 'cpd_prob_freq_delta' : {'change_features':['prob_freq_delta_weight'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        # , 'cpd_prob_causality_delta' : {'change_features':['causality_delta'], 'method':'cpd_pelt', 'smooth' : '3'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        # , 'cpd_prob_parallel_delta' : {'change_features':['parallel_delta'], 'method':'cpd_pelt', 'smooth' : '3'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        # , 'cramersv_frequency' : {'change_features':['frequency_cramersv'], 'method':'cpd_pelt', 'smooth' : '3'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'

        ### Time Perspective
        , 'cpd_time_avg_delta' : {'change_features':['time_avg_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        , 'cpd_time_std_delta' : {'change_features':['time_std_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'

        ### Resource Perspective
        # , 'cpd_role_unique_delta' : {'change_features':['role_unique_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        # , 'cpd_role_entropy_delta' : {'change_features':['role_entropy_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        , 'cpd_role_encoding_frequency_delta' : {'change_features':['role_encoding_frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        # , 'cpd_role_encoding_probability_delta' : {'change_features':['role_encoding_probability_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'

        # , 'cpd_resource_unique_delta' : {'change_features':['resource_unique_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
        # , 'cpd_resource_entropy_delta' : {'change_features':['resource_entropy_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
        , 'cpd_resource_encoding_frequency_delta' : {'change_features':['resource_encoding_frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
        # , 'cpd_resource_encoding_probability_delta' : {'change_features':['resource_encoding_probability_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1

        ### Data Perspective
        , 'cpd_amount_avg_delta' : {'change_features':['amount_avg_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        # , 'cpd_amount_std_delta' : {'change_features':['amount_std_delta'], 'method':'cpd_pelt', 'smooth' : '3'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1'
        , 'cpd_BudgetNumber_unique_delta' : {'change_features':['BudgetNumber_unique_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
        , 'cpd_BudgetNumber_entropy_delta' : {'change_features':['BudgetNumber_entropy_delta'], 'method':'cpd_pelt', 'smooth' : '3', 'pen': '5'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
        # , 'cpd_BudgetNumber_encoding_frequency_delta' : {'change_features':['BudgetNumber_encoding_frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
        # , 'cpd_BudgetNumber_encoding_probability_delta' : {'change_features':['BudgetNumber_encoding_probability_delta'], 'method':'cpd_pelt', 'smooth' : '3'} #, 'model' : 'rbf', 'cost' : 'rpt.costs.CostRbf()', 'min_size' : '1', 'jump' : '1
    }
    , 'threshold_strategy' : 
    {
        'gtest_frequency' : {'change_features':['frequency_gtest_pvalue'], 'method':'comparison_operator', 'operator' : 'le', 'threshold_value' : '0.05', 'smooth' : '3'}
        # , 'cramersv_frequency' : {'change_features':['frequency_cramersv'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
        # , 'fixed_frequency_delta_percentage' : {'change_features':['frequency_delta_percentage'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
    }
}

# Setting Detection Task
TMPD_instance.set_detection_task(detection_task_strategy_dict)

# Executing the Detection Task
TMPD_instance.run_detection_task()

# Showing Detection Task Results
TMPD_instance.get_detection_task()
# Out:
#      detection_strategy                      detection_feature  \
# 0  time_series_strategy                    cpd_frequency_delta
# 1  time_series_strategy                    cpd_prob_freq_delta
# 2  time_series_strategy                     cpd_time_avg_delta
# 3  time_series_strategy                     cpd_time_std_delta
# 4  time_series_strategy      cpd_role_encoding_frequency_delta
# 5  time_series_strategy  cpd_resource_encoding_frequency_delta
# 6  time_series_strategy                   cpd_amount_avg_delta
# 7  time_series_strategy          cpd_BudgetNumber_unique_delta
# 8  time_series_strategy         cpd_BudgetNumber_entropy_delta
# 9    threshold_strategy                        gtest_frequency
#
#   detection_results
# 0          [13, 65]
# 1          [12, 65]
# 2          [12, 65]
# 3          [12, 65]
# 4          [12, 65]
# 5          [13, 65]
# 6          [25, 65]
# 7          [10, 65]
# 8              [65]
# 9      [10, 17, 65]

# %%
### Grounding truth
# No ground truth available for real dataset. Skipping this step.

# %%
### Validation metrics
# No ground truth available for real dataset. Skipping validation metrics calculation.

# %%
### Display Detection Task Results 
detection_task_results = TMPD_instance.get_detection_task()
for result in detection_task_results.itertuples():
    fig, axarr = rpt.display(
        signal=TMPD_instance.get_change_representation()[TMPD_instance.detection_task_strategy_dict[result.detection_strategy][result.detection_feature]['change_features']],
        true_chg_pts=[],  # Provide empty list when no ground truth
        computed_chg_pts=result.detection_results,
        computed_chg_pts_color="k",
        computed_chg_pts_linewidth=4,
        computed_chg_pts_linestyle="--",
        computed_chg_pts_alpha=1,
        figsize=(15, 2)
    )
    plt.suptitle(
        "Dataset: " + log_path.split("\\")[-2]
        + " - Feature: " + result.detection_feature,
        fontsize=20
    )
    plt.subplots_adjust(top=0.8)
    plt.show()

# %% [markdown]
# ## Step 6a - Setting Localization Task

# %%
# Setting Localization Task
reference_window_index=0 
detection_window_index=14

TMPD_instance.set_localization_task(reference_window_index=reference_window_index, detection_window_index=detection_window_index, pvalue_threshold=0.05, effect_threshold=0.2, presence_percentage_threshold=0.01, pseudo_count=5, perspectives=['data'])

# Executing Localization Task
TMPD_instance.run_localization_task()

# Showing Localization Task Results
significant_transition_changes, high_level_changes, reference_bpmn_text, detection_bpmn_text = TMPD_instance.get_localization_task(show_localization_dfg=True, show_original_dfg=False, show_original_bpmn=False, show_annotations=True)

# %%
significant_transition_changes.to_excel("Experiments/Results/Experiment5-Localization_Task_Significant_Transition_Changes.xlsx", index=False)
significant_transition_changes
# Out:
#                                                                             transition  \
# 0       (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)
# 1       (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)
# 2       (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)
# 3   (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 4   (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 5   (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 6     (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 7     (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 8     (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 9     (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 10    (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 11    (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 12         (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)
# 13         (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)
# 14         (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)
# 15                         (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)
# 16          (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)
# 17          (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)
# 18          (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)
# 19                (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)
# 20                (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)
# 21                (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)
# 22            (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)
# 23            (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)
# 24            (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)
# 25              (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)
# 26              (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)
# 27              (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)
# 28         (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)
# 29         (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)
# 30         (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)
# 31           (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)
# 32           (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)
# 33           (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)
# 34       (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 35       (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 36       (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_FINAL_APPROVED_by_SUPERVISOR)
# 37         (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_ADMINISTRATION)
# 38         (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_ADMINISTRATION)
# 39         (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_ADMINISTRATION)
# 40           (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_PRE_APPROVER)
# 41           (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_PRE_APPROVER)
# 42           (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_PRE_APPROVER)
# 43             (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_SUPERVISOR)
# 44             (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_SUPERVISOR)
# 45             (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_REJECTED_by_SUPERVISOR)
# 46                                                              (Payment_Handled, END)
# 47                                                  (Request_Payment, Payment_Handled)
# 48                                          (START, Declaration_SUBMITTED_by_EMPLOYEE)
#
#                             feature perspective       transition_status  \
# 0              numerical_avg_Amount        data                     new
# 1              numerical_std_Amount        data                     new
# 2   categorical_unique_BudgetNumber        data                     new
# 3              numerical_avg_Amount        data                     new
# 4              numerical_std_Amount        data                     new
# 5   categorical_unique_BudgetNumber        data                     new
# 6              numerical_avg_Amount        data                     new
# 7              numerical_std_Amount        data                     new
# 8   categorical_unique_BudgetNumber        data                     new
# 9              numerical_avg_Amount        data                 deleted
# 10             numerical_std_Amount        data                 deleted
# 11  categorical_unique_BudgetNumber        data                 deleted
# 12             numerical_avg_Amount        data                 deleted
# 13             numerical_std_Amount        data                 deleted
# 14  categorical_unique_BudgetNumber        data                 deleted
# 15             numerical_std_Amount        data  significant difference
# 16             numerical_avg_Amount        data                     new
# 17             numerical_std_Amount        data                     new
# 18  categorical_unique_BudgetNumber        data                     new
# 19             numerical_avg_Amount        data                 deleted
# 20             numerical_std_Amount        data                 deleted
# 21  categorical_unique_BudgetNumber        data                 deleted
# 22             numerical_avg_Amount        data                 deleted
# 23             numerical_std_Amount        data                 deleted
# 24  categorical_unique_BudgetNumber        data                 deleted
# 25             numerical_avg_Amount        data                 deleted
# 26             numerical_std_Amount        data                 deleted
# 27  categorical_unique_BudgetNumber        data                 deleted
# 28             numerical_avg_Amount        data                     new
# 29             numerical_std_Amount        data                     new
# 30  categorical_unique_BudgetNumber        data                     new
# 31             numerical_avg_Amount        data                 deleted
# 32             numerical_std_Amount        data                 deleted
# 33  categorical_unique_BudgetNumber        data                 deleted
# 34             numerical_avg_Amount        data                 deleted
# 35             numerical_std_Amount        data                 deleted
# 36  categorical_unique_BudgetNumber        data                 deleted
# 37             numerical_avg_Amount        data                     new
# 38             numerical_std_Amount        data                     new
# 39  categorical_unique_BudgetNumber        data                     new
# 40             numerical_avg_Amount        data                 deleted
# 41             numerical_std_Amount        data                 deleted
# 42  categorical_unique_BudgetNumber        data                 deleted
# 43             numerical_avg_Amount        data                 deleted
# 44             numerical_std_Amount        data                 deleted
# 45  categorical_unique_BudgetNumber        data                 deleted
# 46             numerical_std_Amount        data  significant difference
# 47             numerical_std_Amount        data  significant difference
# 48             numerical_std_Amount        data  significant difference
#
#                                                                       activity_status  \
# 0   new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)
# 1   new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)
# 2   new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)
# 3                                         new(Declaration_APPROVED_by_ADMINISTRATION)
# 4                                         new(Declaration_APPROVED_by_ADMINISTRATION)
# 5                                         new(Declaration_APPROVED_by_ADMINISTRATION)
# 6                                           new(Declaration_APPROVED_by_BUDGET_OWNER)
# 7                                           new(Declaration_APPROVED_by_BUDGET_OWNER)
# 8                                           new(Declaration_APPROVED_by_BUDGET_OWNER)
# 9                                       deleted(Declaration_APPROVED_by_PRE_APPROVER)
# 10                                      deleted(Declaration_APPROVED_by_PRE_APPROVER)
# 11                                      deleted(Declaration_APPROVED_by_PRE_APPROVER)
# 12                                           deleted(Declaration_REJECTED_by_MISSING)
# 13                                           deleted(Declaration_REJECTED_by_MISSING)
# 14                                           deleted(Declaration_REJECTED_by_MISSING)
# 15                                                                          no change
# 16                                        new(Declaration_REJECTED_by_ADMINISTRATION)
# 17                                        new(Declaration_REJECTED_by_ADMINISTRATION)
# 18                                        new(Declaration_REJECTED_by_ADMINISTRATION)
# 19                                           deleted(Declaration_REJECTED_by_MISSING)
# 20                                           deleted(Declaration_REJECTED_by_MISSING)
# 21                                           deleted(Declaration_REJECTED_by_MISSING)
# 22                                      deleted(Declaration_REJECTED_by_PRE_APPROVER)
# 23                                      deleted(Declaration_REJECTED_by_PRE_APPROVER)
# 24                                      deleted(Declaration_REJECTED_by_PRE_APPROVER)
# 25                                        deleted(Declaration_REJECTED_by_SUPERVISOR)
# 26                                        deleted(Declaration_REJECTED_by_SUPERVISOR)
# 27                                        deleted(Declaration_REJECTED_by_SUPERVISOR)
# 28                                        new(Declaration_APPROVED_by_ADMINISTRATION)
# 29                                        new(Declaration_APPROVED_by_ADMINISTRATION)
# 30                                        new(Declaration_APPROVED_by_ADMINISTRATION)
# 31                                      deleted(Declaration_APPROVED_by_PRE_APPROVER)
# 32                                      deleted(Declaration_APPROVED_by_PRE_APPROVER)
# 33                                      deleted(Declaration_APPROVED_by_PRE_APPROVER)
# 34                                                                          no change
# 35                                                                          no change
# 36                                                                          no change
# 37                                        new(Declaration_REJECTED_by_ADMINISTRATION)
# 38                                        new(Declaration_REJECTED_by_ADMINISTRATION)
# 39                                        new(Declaration_REJECTED_by_ADMINISTRATION)
# 40                                      deleted(Declaration_REJECTED_by_PRE_APPROVER)
# 41                                      deleted(Declaration_REJECTED_by_PRE_APPROVER)
# 42                                      deleted(Declaration_REJECTED_by_PRE_APPROVER)
# 43                                        deleted(Declaration_REJECTED_by_SUPERVISOR)
# 44                                        deleted(Declaration_REJECTED_by_SUPERVISOR)
# 45                                        deleted(Declaration_REJECTED_by_SUPERVISOR)
# 46                                                                          no change
# 47                                                                          no change
# 48                                                                          no change
#
#     p_value  effect_size  ref_value  det_value  dif_value
# 0    0.0000       1.0000     0.0000   101.7112   101.7112
# 1    0.0000       1.0000     0.0000   161.0560   161.0560
# 2    0.0000       1.0000     0.0000     1.0000     1.0000
# 3    0.0000       1.0000     0.0000    80.8178    80.8178
# 4    0.0000       1.0000     0.0000   124.5736   124.5736
# 5    0.0000       1.0000     0.0000     1.0000     1.0000
# 6    0.0000       1.0000     0.0000    99.2849    99.2849
# 7    0.0000       1.0000     0.0000   161.1439   161.1439
# 8    0.0000       1.0000     0.0000     1.0000     1.0000
# 9    0.0000       1.0000    68.5442     0.0000   -68.5442
# 10   0.0000       1.0000    86.3522     0.0000   -86.3522
# 11   0.0000       1.0000     1.0000     0.0000    -1.0000
# 12   0.0000       1.0000    64.6080     0.0000   -64.6080
# 13   0.0000       1.0000   100.4905     0.0000  -100.4905
# 14   0.0000       1.0000     1.0000     0.0000    -1.0000
# 15   0.0000       0.5537   104.6040   140.4015    35.7974
# 16   0.0000       1.0000     0.0000   107.2074   107.2074
# 17   0.0000       1.0000     0.0000   122.9236   122.9236
# 18   0.0000       1.0000     0.0000     1.0000     1.0000
# 19   0.0000       1.0000    87.6822     0.0000   -87.6822
# 20   0.0000       1.0000   108.6438     0.0000  -108.6438
# 21   0.0000       1.0000     1.0000     0.0000    -1.0000
# 22   0.0000       1.0000   127.3832     0.0000  -127.3832
# 23   0.0000       1.0000   116.0101     0.0000  -116.0101
# 24   0.0000       1.0000     1.0000     0.0000    -1.0000
# 25   0.0000       1.0000   121.3915     0.0000  -121.3915
# 26   0.0000       1.0000   159.7203     0.0000  -159.7203
# 27   0.0000       1.0000     1.0000     0.0000    -1.0000
# 28   0.0000       1.0000     0.0000    90.9769    90.9769
# 29   0.0000       1.0000     0.0000   141.6388   141.6388
# 30   0.0000       1.0000     0.0000     1.0000     1.0000
# 31   0.0000       1.0000    68.5442     0.0000   -68.5442
# 32   0.0000       1.0000    86.3522     0.0000   -86.3522
# 33   0.0000       1.0000     1.0000     0.0000    -1.0000
# 34   0.0000       1.0000    83.5188     0.0000   -83.5188
# 35   0.0000       1.0000   109.8686     0.0000  -109.8686
# 36   0.0000       1.0000     1.0000     0.0000    -1.0000
# 37   0.0000       1.0000     0.0000   107.2074   107.2074
# 38   0.0000       1.0000     0.0000   122.9236   122.9236
# 39   0.0000       1.0000     0.0000     1.0000     1.0000
# 40   0.0000       1.0000   121.3915     0.0000  -121.3915
# 41   0.0000       1.0000   114.6104     0.0000  -114.6104
# 42   0.0000       1.0000     1.0000     0.0000    -1.0000
# 43   0.0000       1.0000   121.3915     0.0000  -121.3915
# 44   0.0000       1.0000   159.7203     0.0000  -159.7203
# 45   0.0000       1.0000     1.0000     0.0000    -1.0000
# 46   0.0000       0.5534   104.7542   140.5291    35.7749
# 47   0.0000       0.5537   104.6040   140.4015    35.7974
# 48   0.0000       0.5547   104.1684   140.0311    35.8626

# %%
high_level_changes
# Out:
# {'Transitions with variations in numerical_avg_Amount': [('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_APPROVED_by_BUDGET_OWNER'),
#   ('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_BUDGET_OWNER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_PRE_APPROVER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_FINAL_APPROVED_by_SUPERVISOR',
#    'Declaration_REJECTED_by_MISSING'),
#   ('Declaration_REJECTED_by_ADMINISTRATION',
#    'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_ADMINISTRATION'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_PRE_APPROVER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_ADMINISTRATION'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_PRE_APPROVER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')],
#  'Transitions with variations in numerical_std_Amount': [('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_APPROVED_by_BUDGET_OWNER'),
#   ('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_BUDGET_OWNER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_PRE_APPROVER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_FINAL_APPROVED_by_SUPERVISOR',
#    'Declaration_REJECTED_by_MISSING'),
#   ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'),
#   ('Declaration_REJECTED_by_ADMINISTRATION',
#    'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_ADMINISTRATION'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_PRE_APPROVER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_ADMINISTRATION'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_PRE_APPROVER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'),
#   ('Payment_Handled', 'END'),
#   ('Request_Payment', 'Payment_Handled'),
#   ('START', 'Declaration_SUBMITTED_by_EMPLOYEE')],
#  'Transitions with variations in categorical_unique_BudgetNumber': [('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_APPROVED_by_BUDGET_OWNER'),
#   ('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_BUDGET_OWNER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_PRE_APPROVER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_FINAL_APPROVED_by_SUPERVISOR',
#    'Declaration_REJECTED_by_MISSING'),
#   ('Declaration_REJECTED_by_ADMINISTRATION',
#    'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_ADMINISTRATION'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_PRE_APPROVER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_ADMINISTRATION'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_PRE_APPROVER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')],
#  'New transitions added to the process': [('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_APPROVED_by_ADMINISTRATION',
#    'Declaration_APPROVED_by_BUDGET_OWNER'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_ADMINISTRATION'),
#   ('Declaration_REJECTED_by_ADMINISTRATION',
#    'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_APPROVED_by_BUDGET_OWNER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_ADMINISTRATION')],
#  'Deleted transitions from the process': [('Declaration_REJECTED_by_SUPERVISOR',
#    'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_REJECTED_by_PRE_APPROVER'),
#   ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'),
#   ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_APPROVED_by_PRE_APPROVER'),
#   ('Declaration_APPROVED_by_PRE_APPROVER',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR'),
#   ('Declaration_FINAL_APPROVED_by_SUPERVISOR',
#    'Declaration_REJECTED_by_MISSING'),
#   ('Declaration_SUBMITTED_by_EMPLOYEE',
#    'Declaration_FINAL_APPROVED_by_SUPERVISOR')],
#  'New activities added to the process': ['Declaration_REJECTED_by_ADMINISTRATION',
#   'Declaration_APPROVED_by_ADMINISTRATION',
#   'Declaration_APPROVED_by_BUDGET_OWNER'],
#  'Deleted activities from the process': ['Declaration_APPROVED_by_PRE_APPROVER',
#   'Declaration_REJECTED_by_SUPERVISOR',
#   'Declaration_REJECTED_by_MISSING',
#   'Declaration_REJECTED_by_PRE_APPROVER']}

# %%
reference_bpmn_text, detection_bpmn_text
# Out:
# ("Sequence( Loop( Sequence( Loop( 'Declaration_SUBMITTED_by_EMPLOYEE', Sequence( Conditional( 'Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_PRE_APPROVER' ), 'Declaration_REJECTED_by_EMPLOYEE' ) ), 'Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR' ), 'Declaration_REJECTED_by_MISSING' ), 'Request_Payment', 'Payment_Handled' )",
#  "Sequence( Loop( 'Declaration_SUBMITTED_by_EMPLOYEE', Sequence( 'Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE' ) ), 'Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment', 'Payment_Handled' )")

# %%
# Debug

## Getting the reference window
TMPD_instance.run_process_representation(TMPD_instance.transition_log[TMPD_instance.get_windowing_strategy()[reference_window_index]['start']:TMPD_instance.get_windowing_strategy()[reference_window_index]['end']])
reference_window_df = TMPD_instance.get_process_representation()
reference_window_df
# Out:
#                                                                                    frequency  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR         95
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                  19
#                                          Request_Payment                                 350
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                25
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                14
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                 15
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                 11
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER             95
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR        273
#                                          Declaration_REJECTED_by_PRE_APPROVER             16
#                                          Declaration_REJECTED_by_SUPERVISOR               11
# Payment_Handled                          END                                             349
# Request_Payment                          Payment_Handled                                 350
# START                                    Declaration_SUBMITTED_by_EMPLOYEE               357
#
#                                                                                    percentual  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0475
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING               0.0095
#                                          Request_Payment                               0.1750
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE             0.0125
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE             0.0070
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE              0.0075
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE              0.0055
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER          0.0475
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR      0.1365
#                                          Declaration_REJECTED_by_PRE_APPROVER          0.0080
#                                          Declaration_REJECTED_by_SUPERVISOR            0.0055
# Payment_Handled                          END                                           0.1745
# Request_Payment                          Payment_Handled                               0.1750
# START                                    Declaration_SUBMITTED_by_EMPLOYEE             0.1785
#
#                                                                                    probability  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR       1.0000
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                0.0515
#                                          Request_Payment                                0.9485
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              1.0000
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE              1.0000
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE               1.0000
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE               1.0000
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER           0.2405
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       0.6911
#                                          Declaration_REJECTED_by_PRE_APPROVER           0.0405
#                                          Declaration_REJECTED_by_SUPERVISOR             0.0278
# Payment_Handled                          END                                            1.0000
# Request_Payment                          Payment_Handled                                1.0000
# START                                    Declaration_SUBMITTED_by_EMPLOYEE              1.0000
#
#                                                                                    causality  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR          1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                   0
#                                          Request_Payment                                   0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                 1
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                 1
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                  1
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                  1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR          0
#                                          Declaration_REJECTED_by_PRE_APPROVER              0
#                                          Declaration_REJECTED_by_SUPERVISOR                0
# Payment_Handled                          END                                               1
# Request_Payment                          Payment_Handled                                   1
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                 1
#
#                                                                                    parallel  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                  0
#                                          Request_Payment                                  0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                 0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                 0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR         0
#                                          Declaration_REJECTED_by_PRE_APPROVER             0
#                                          Declaration_REJECTED_by_SUPERVISOR               0
# Payment_Handled                          END                                              0
# Request_Payment                          Payment_Handled                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                0
#
#                                                                                    choice  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                1
#                                          Request_Payment                                1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE              0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE               0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE               0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER           1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       1
#                                          Declaration_REJECTED_by_PRE_APPROVER           1
#                                          Declaration_REJECTED_by_SUPERVISOR             1
# Payment_Handled                          END                                            0
# Request_Payment                          Payment_Handled                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE              0
#
#                                                                                    loop  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR     1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING              1
#                                          Request_Payment                              0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE            1
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE            1
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE             1
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE             1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER         1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR     1
#                                          Declaration_REJECTED_by_PRE_APPROVER         1
#                                          Declaration_REJECTED_by_SUPERVISOR           1
# Payment_Handled                          END                                          0
# Request_Payment                          Payment_Handled                              0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE            0
#
#                                                                                    time_avg_timestamp  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR           2534.8918
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                   25020.5263
#                                          Request_Payment                                    4888.7406
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                  3129.1407
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                 21756.0845
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                   1533.4522
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                   5109.3591
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER               2341.8467
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR            966.4593
#                                          Declaration_REJECTED_by_PRE_APPROVER               6661.4469
#                                          Declaration_REJECTED_by_SUPERVISOR                 1555.4621
# Payment_Handled                          END                                                   0.0000
# Request_Payment                          Payment_Handled                                    6514.9430
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     0.0000
#
#                                                                                    time_std_timestamp  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR           3229.9091
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                   96273.6389
#                                          Request_Payment                                    6542.6776
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                  9075.1464
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                 51502.8523
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                   1925.4831
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                   5567.1368
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER               9595.6556
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR           7359.3092
#                                          Declaration_REJECTED_by_PRE_APPROVER              25511.0557
#                                          Declaration_REJECTED_by_SUPERVISOR                 5137.7431
# Payment_Handled                          END                                                   0.0000
# Request_Payment                          Payment_Handled                                    6281.2546
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     0.0000
#
#                                                                                    categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                  95
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                           19
#                                          Request_Payment                                                                                            0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                         25
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                         14
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                          15
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                          11
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                                      95
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 273
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                                      16
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                        11
# Payment_Handled                          END                                                                                                        0
# Request_Payment                          Payment_Handled                                                                                            0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                        357
#
#                                                                                    categorical_encoding_frequency_resource_STAFF MEMBER->SYSTEM  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                      0
#                                          Request_Payment                                                                                    350
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                                 0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                   0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_resource_SYSTEM->SYSTEM  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                0
#                                          Request_Payment                                                                                0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                              0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                              0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                           0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                             0
# Payment_Handled                          END                                                                                          349
# Request_Payment                          Payment_Handled                                                                              350
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                              0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                          0
#                                          Request_Payment                                                                                          0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                         0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                         0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                                     0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                                     0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                       0
# Payment_Handled                          END                                                                                                      0
# Request_Payment                          Payment_Handled                                                                                          0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
#
#                                                                                    categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                      0
#                                          Request_Payment                                                                                      0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                                 0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                   0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                      0
#                                          Request_Payment                                                                                      0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                                 0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                   0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                0
#                                          Request_Payment                                                                                0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                             25
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                              0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                           0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                             0
# Payment_Handled                          END                                                                                            0
# Request_Payment                          Payment_Handled                                                                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                            357
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->PRE_APPROVER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                    0
#                                          Request_Payment                                                                                    0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                   0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                   0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                              95
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                              16
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                 0
# Payment_Handled                          END                                                                                                0
# Request_Payment                          Payment_Handled                                                                                    0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                  0
#                                          Request_Payment                                                                                  0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       273
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                             0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                              11
# Payment_Handled                          END                                                                                              0
# Request_Payment                          Payment_Handled                                                                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    categorical_encoding_frequency_role_MISSING->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                      0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                               0
#                                          Request_Payment                                                                               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                             0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                            14
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                              0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                              0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                          0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                      0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                          0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                            0
# Payment_Handled                          END                                                                                           0
# Request_Payment                          Payment_Handled                                                                               0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                             0
#
#                                                                                    categorical_encoding_frequency_role_MISSING->MISSING  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                     0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                              0
#                                          Request_Payment                                                                              0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                            0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                            0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                             0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                             0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                         0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                     0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                         0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                           0
# Payment_Handled                          END                                                                                          0
# Request_Payment                          Payment_Handled                                                                              0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                            0
#
#                                                                                    categorical_encoding_frequency_role_PRE_APPROVER->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                    0
#                                          Request_Payment                                                                                    0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                  15
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                   0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                               0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                               0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                 0
# Payment_Handled                          END                                                                                                0
# Request_Payment                          Payment_Handled                                                                                    0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
#
#                                                                                    categorical_encoding_frequency_role_PRE_APPROVER->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                            95
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                      0
#                                          Request_Payment                                                                                      0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                                 0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                   0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_SUPERVISOR->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                  0
#                                          Request_Payment                                                                                  0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                11
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                             0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                               0
# Payment_Handled                          END                                                                                              0
# Request_Payment                          Payment_Handled                                                                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    categorical_encoding_frequency_role_SUPERVISOR->MISSING  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                19
#                                          Request_Payment                                                                                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                            0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                        0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                            0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                              0
# Payment_Handled                          END                                                                                             0
# Request_Payment                          Payment_Handled                                                                                 0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                               0
#
#                                                                                    categorical_encoding_frequency_role_SUPERVISOR->UNDEFINED  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                   0
#                                          Request_Payment                                                                                 350
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                  0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                              0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                                0
# Payment_Handled                          END                                                                                               0
# Request_Payment                          Payment_Handled                                                                                   0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
#
#                                                                                    categorical_encoding_frequency_role_UNDEFINED->UNDEFINED  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                                                  0
#                                          Request_Payment                                                                                  0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
#                                          Declaration_REJECTED_by_PRE_APPROVER                                                             0
#                                          Declaration_REJECTED_by_SUPERVISOR                                                               0
# Payment_Handled                          END                                                                                            349
# Request_Payment                          Payment_Handled                                                                                350
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    numerical_avg_Amount  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR               68.5442
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                        64.6080
#                                          Request_Payment                                        80.2701
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                     131.1028
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                      87.6822
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                      127.3832
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                      121.3915
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                   68.5442
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR               83.5188
#                                          Declaration_REJECTED_by_PRE_APPROVER                  121.3915
#                                          Declaration_REJECTED_by_SUPERVISOR                    121.3915
# Payment_Handled                          END                                                    80.2649
# Request_Payment                          Payment_Handled                                        80.2701
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                      78.6962
#
#                                                                                    categorical_unique_BudgetNumber  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                         1
#                                          Request_Payment                                                         1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                       1
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                       1
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                        1
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                        1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                    1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
#                                          Declaration_REJECTED_by_PRE_APPROVER                                    1
#                                          Declaration_REJECTED_by_SUPERVISOR                                      1
# Payment_Handled                          END                                                                     1
# Request_Payment                          Payment_Handled                                                         1
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                       1
#
#                                                                                    numerical_std_Amount  \
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR               86.3522
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                       100.4905
#                                          Request_Payment                                       104.6040
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                     132.3362
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                     108.6438
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                      116.0101
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                      159.7203
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                   86.3522
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR              109.8686
#                                          Declaration_REJECTED_by_PRE_APPROVER                  114.6104
#                                          Declaration_REJECTED_by_SUPERVISOR                    159.7203
# Payment_Handled                          END                                                   104.7542
# Request_Payment                          Payment_Handled                                       104.6040
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     104.1684
#
#                                                                                    categorical_entropy_BudgetNumber
# activity_from                            activity_to
# Declaration_APPROVED_by_PRE_APPROVER     Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
# Declaration_FINAL_APPROVED_by_SUPERVISOR Declaration_REJECTED_by_MISSING                                     0.0000
#                                          Request_Payment                                                     0.0000
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000
# Declaration_REJECTED_by_MISSING          Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000
# Declaration_REJECTED_by_PRE_APPROVER     Declaration_REJECTED_by_EMPLOYEE                                    0.0000
# Declaration_REJECTED_by_SUPERVISOR       Declaration_REJECTED_by_EMPLOYEE                                    0.0000
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_PRE_APPROVER                                0.0000
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
#                                          Declaration_REJECTED_by_PRE_APPROVER                                0.0000
#                                          Declaration_REJECTED_by_SUPERVISOR                                  0.0000
# Payment_Handled                          END                                                                 0.0000
# Request_Payment                          Payment_Handled                                                     0.0000
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000

# %%
## Getting the detection window
TMPD_instance.run_process_representation(TMPD_instance.transition_log[TMPD_instance.get_windowing_strategy()[detection_window_index]['start']:TMPD_instance.get_windowing_strategy()[detection_window_index]['end']])
detection_window_df = TMPD_instance.get_process_representation()
detection_window_df
# Out:
#                                                                                    frequency  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER            120
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR        175
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR        117
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                 292
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                 24
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                32
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION          304
#                                          Declaration_REJECTED_by_ADMINISTRATION           24
# Payment_Handled                          END                                             291
# Request_Payment                          Payment_Handled                                 292
# START                                    Declaration_SUBMITTED_by_EMPLOYEE               295
#
#                                                                                    percentual  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER          0.0600
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0875
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR      0.0585
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                               0.1460
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE              0.0120
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE             0.0160
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION        0.1520
#                                          Declaration_REJECTED_by_ADMINISTRATION        0.0120
# Payment_Handled                          END                                           0.1455
# Request_Payment                          Payment_Handled                               0.1460
# START                                    Declaration_SUBMITTED_by_EMPLOYEE             0.1475
#
#                                                                                    probability  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER           0.4068
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       0.5932
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR       1.0000
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                1.0000
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE               1.0000
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              1.0000
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION         0.9268
#                                          Declaration_REJECTED_by_ADMINISTRATION         0.0732
# Payment_Handled                          END                                            1.0000
# Request_Payment                          Payment_Handled                                1.0000
# START                                    Declaration_SUBMITTED_by_EMPLOYEE              1.0000
#
#                                                                                    causality  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR          0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR          1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                   1
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                  1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                 1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION            0
#                                          Declaration_REJECTED_by_ADMINISTRATION            0
# Payment_Handled                          END                                               1
# Request_Payment                          Payment_Handled                                   1
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                 1
#
#                                                                                    parallel  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR         0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                  0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION           0
#                                          Declaration_REJECTED_by_ADMINISTRATION           0
# Payment_Handled                          END                                              0
# Request_Payment                          Payment_Handled                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                0
#
#                                                                                    choice  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER           1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR       1
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE              0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION         1
#                                          Declaration_REJECTED_by_ADMINISTRATION         1
# Payment_Handled                          END                                            0
# Request_Payment                          Payment_Handled                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE              0
#
#                                                                                    loop  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER         0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR     0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR     0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                              0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE             1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE            1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION       0
#                                          Declaration_REJECTED_by_ADMINISTRATION       1
# Payment_Handled                          END                                          0
# Request_Payment                          Payment_Handled                              0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE            0
#
#                                                                                    time_avg_timestamp  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER               3126.0833
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR           3116.9659
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR           4101.8400
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                    3319.5731
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                   4689.1528
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                  3552.4349
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION             4511.7662
#                                          Declaration_REJECTED_by_ADMINISTRATION             8800.6507
# Payment_Handled                          END                                                   0.0000
# Request_Payment                          Payment_Handled                                    4725.6183
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     0.0000
#
#                                                                                    time_std_timestamp  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER               4443.2207
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR           4223.2603
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR           3763.9124
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                    4206.5266
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                   4309.9666
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                  4573.3373
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION            22912.1205
#                                          Declaration_REJECTED_by_ADMINISTRATION            29740.2941
# Payment_Handled                          END                                                   0.0000
# Request_Payment                          Payment_Handled                                    1613.7324
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     0.0000
#
#                                                                                    categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                     120
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 175
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 117
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                            0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                          24
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                         32
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                   304
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                    24
# Payment_Handled                          END                                                                                                        0
# Request_Payment                          Payment_Handled                                                                                            0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                        295
#
#                                                                                    categorical_encoding_frequency_resource_STAFF MEMBER->SYSTEM  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                    292
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_resource_SYSTEM->SYSTEM  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                              0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                         0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                         0
# Payment_Handled                          END                                                                                          291
# Request_Payment                          Payment_Handled                                                                              292
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                              0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                   120
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                                 0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                          0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                         0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                   0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                   0
# Payment_Handled                          END                                                                                                      0
# Request_Payment                          Payment_Handled                                                                                          0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                        0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                    24
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_ADMINISTRATION->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                   0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             175
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                               0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                        0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                       0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                      0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                                 0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                                 0
# Payment_Handled                          END                                                                                                    0
# Request_Payment                          Payment_Handled                                                                                        0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                      0
#
#                                                                                    categorical_encoding_frequency_role_BUDGET OWNER->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                               0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                    0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                   0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                             0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                             0
# Payment_Handled                          END                                                                                                0
# Request_Payment                          Payment_Handled                                                                                    0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                  0
#
#                                                                                    categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                           117
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                               0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                               0
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                                 0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                             0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                      0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                     0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                             304
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                              24
# Payment_Handled                          END                                                                                                  0
# Request_Payment                          Payment_Handled                                                                                      0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                    0
#
#                                                                                    categorical_encoding_frequency_role_EMPLOYEE->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                           0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                       0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                               0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                             32
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                         0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                         0
# Payment_Handled                          END                                                                                            0
# Request_Payment                          Payment_Handled                                                                                0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                            295
#
#                                                                                    categorical_encoding_frequency_role_SUPERVISOR->EMPLOYEE  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                  0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                           0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                           0
# Payment_Handled                          END                                                                                              0
# Request_Payment                          Payment_Handled                                                                                  0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    categorical_encoding_frequency_role_SUPERVISOR->UNDEFINED  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                              0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                          0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                 292
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                  0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                            0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                            0
# Payment_Handled                          END                                                                                               0
# Request_Payment                          Payment_Handled                                                                                   0
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                 0
#
#                                                                                    categorical_encoding_frequency_role_UNDEFINED->UNDEFINED  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                                             0
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                                         0
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                                                  0
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                                                 0
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                                                0
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                                           0
#                                          Declaration_REJECTED_by_ADMINISTRATION                                                           0
# Payment_Handled                          END                                                                                            291
# Request_Payment                          Payment_Handled                                                                                292
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                                                0
#
#                                                                                    numerical_avg_Amount  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                  101.7112
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR               80.8178
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR               99.2849
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                        88.2173
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                      107.2074
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                     139.7037
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                 90.9769
#                                          Declaration_REJECTED_by_ADMINISTRATION                107.2074
# Payment_Handled                          END                                                    87.8862
# Request_Payment                          Payment_Handled                                        88.2173
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                      87.1805
#
#                                                                                    categorical_unique_BudgetNumber  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                    1
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                                1
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                         1
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                        1
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                       1
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                                  1
#                                          Declaration_REJECTED_by_ADMINISTRATION                                  1
# Payment_Handled                          END                                                                     1
# Request_Payment                          Payment_Handled                                                         1
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                       1
#
#                                                                                    numerical_std_Amount  \
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                  161.0560
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR              124.5736
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR              161.1439
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                       140.4015
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                      122.9236
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                     137.3533
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                141.6388
#                                          Declaration_REJECTED_by_ADMINISTRATION                122.9236
# Payment_Handled                          END                                                   140.5291
# Request_Payment                          Payment_Handled                                       140.4015
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                     140.0311
#
#                                                                                    categorical_entropy_BudgetNumber
# activity_from                            activity_to
# Declaration_APPROVED_by_ADMINISTRATION   Declaration_APPROVED_by_BUDGET_OWNER                                0.0000
#                                          Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
# Declaration_APPROVED_by_BUDGET_OWNER     Declaration_FINAL_APPROVED_by_SUPERVISOR                            0.0000
# Declaration_FINAL_APPROVED_by_SUPERVISOR Request_Payment                                                     0.0000
# Declaration_REJECTED_by_ADMINISTRATION   Declaration_REJECTED_by_EMPLOYEE                                    0.0000
# Declaration_REJECTED_by_EMPLOYEE         Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000
# Declaration_SUBMITTED_by_EMPLOYEE        Declaration_APPROVED_by_ADMINISTRATION                              0.0000
#                                          Declaration_REJECTED_by_ADMINISTRATION                              0.0000
# Payment_Handled                          END                                                                 0.0000
# Request_Payment                          Payment_Handled                                                     0.0000
# START                                    Declaration_SUBMITTED_by_EMPLOYEE                                   0.0000

# %%
## Getting the change representation table
# TMPD_instance.get_change_representation().iloc[detection_window_index]

# %%
## Getting the transition logs for both windows
reference_window = TMPD_instance.transition_log[TMPD_instance.get_windowing_strategy()[reference_window_index]['start']:TMPD_instance.get_windowing_strategy()[reference_window_index]['end']]
detection_window = TMPD_instance.transition_log[TMPD_instance.get_windowing_strategy()[detection_window_index]['start']:TMPD_instance.get_windowing_strategy()[detection_window_index]['end']]

print("Reference Window (Window 0) Transition Log:")
print("Number of transitions:", len(reference_window))
display(reference_window.head())

print("\nDetection Window (Window 18) Transition Log:")
print("Number of transitions:", len(detection_window))
display(detection_window.head())
# Out:
# Reference Window (Window 0) Transition Log:
# Number of transitions: 2000
#              case_id                             activity_from  \
# 0  declaration 86791                                     START
# 1  declaration 86791         Declaration_SUBMITTED_by_EMPLOYEE
# 2  declaration 86791  Declaration_FINAL_APPROVED_by_SUPERVISOR
# 3  declaration 86791                           Request_Payment
# 4  declaration 86791                           Payment_Handled
#
#              timestamp_from   role_from resource_from BudgetNumber_from  \
# 0 2017-01-09 09:49:50+00:00    EMPLOYEE  STAFF MEMBER      budget 86566
# 1 2017-01-09 09:49:50+00:00    EMPLOYEE  STAFF MEMBER      budget 86566
# 2 2017-01-09 11:27:48+00:00  SUPERVISOR  STAFF MEMBER      budget 86566
# 3 2017-01-10 09:34:44+00:00   UNDEFINED        SYSTEM      budget 86566
# 4 2017-01-12 17:31:22+00:00   UNDEFINED        SYSTEM      budget 86566
#
#    Amount_from  event_order_from                               activity_to  \
# 0      26.8512                 0         Declaration_SUBMITTED_by_EMPLOYEE
# 1      26.8512                 0  Declaration_FINAL_APPROVED_by_SUPERVISOR
# 2      26.8512                 1                           Request_Payment
# 3      26.8512                 2                           Payment_Handled
# 4      26.8512                 3                                       END
#
#                timestamp_to     role_to   resource_to BudgetNumber_to  \
# 0 2017-01-09 09:49:50+00:00    EMPLOYEE  STAFF MEMBER    budget 86566
# 1 2017-01-09 11:27:48+00:00  SUPERVISOR  STAFF MEMBER    budget 86566
# 2 2017-01-10 09:34:44+00:00   UNDEFINED        SYSTEM    budget 86566
# 3 2017-01-12 17:31:22+00:00   UNDEFINED        SYSTEM    budget 86566
# 4 2017-01-12 17:31:22+00:00   UNDEFINED        SYSTEM    budget 86566
#
#    Amount_to  event_order_to  case_order  transition_id
# 0    26.8512          0.0000           0              0
# 1    26.8512          1.0000           1              1
# 2    26.8512          2.0000           2              2
# 3    26.8512          3.0000           3              3
# 4    26.8512          3.0000           4              4
# Detection Window (Window 18) Transition Log:
# Number of transitions: 2000
#                  case_id                             activity_from  \
# 14000  declaration 99543                                     START
# 14001  declaration 99543         Declaration_SUBMITTED_by_EMPLOYEE
# 14002  declaration 99543    Declaration_APPROVED_by_ADMINISTRATION
# 14003  declaration 99543  Declaration_FINAL_APPROVED_by_SUPERVISOR
# 14004  declaration 99543                           Request_Payment
#
#                  timestamp_from       role_from resource_from  \
# 14000 2018-01-19 15:46:40+00:00        EMPLOYEE  STAFF MEMBER
# 14001 2018-01-19 15:46:40+00:00        EMPLOYEE  STAFF MEMBER
# 14002 2018-01-19 15:46:47+00:00  ADMINISTRATION  STAFF MEMBER
# 14003 2018-01-22 15:36:16+00:00      SUPERVISOR  STAFF MEMBER
# 14004 2018-01-23 08:14:36+00:00       UNDEFINED        SYSTEM
#
#       BudgetNumber_from  Amount_from  event_order_from  \
# 14000      budget 86566      95.7607             11499
# 14001      budget 86566      95.7607             11499
# 14002      budget 86566      95.7607             11500
# 14003      budget 86566      95.7607             11501
# 14004      budget 86566      95.7607             11502
#
#                                     activity_to              timestamp_to  \
# 14000         Declaration_SUBMITTED_by_EMPLOYEE 2018-01-19 15:46:40+00:00
# 14001    Declaration_APPROVED_by_ADMINISTRATION 2018-01-19 15:46:47+00:00
# 14002  Declaration_FINAL_APPROVED_by_SUPERVISOR 2018-01-22 15:36:16+00:00
# 14003                           Request_Payment 2018-01-23 08:14:36+00:00
# 14004                           Payment_Handled 2018-02-19 17:31:31+00:00
#
#               role_to   resource_to BudgetNumber_to  Amount_to  \
# 14000        EMPLOYEE  STAFF MEMBER    budget 86566    95.7607
# 14001  ADMINISTRATION  STAFF MEMBER    budget 86566    95.7607
# 14002      SUPERVISOR  STAFF MEMBER    budget 86566    95.7607
# 14003       UNDEFINED        SYSTEM    budget 86566    95.7607
# 14004       UNDEFINED        SYSTEM    budget 86566    95.7607
#
#        event_order_to  case_order  transition_id
# 14000      11499.0000           0          14000
# 14001      11500.0000           1          14001
# 14002      11501.0000           2          14002
# 14003      11502.0000           3          14003
# 14004      11503.0000           4          14004

# %%
# Time spans for both windows
print("Reference Window (Window 0) Time Span:")
print("Start:", reference_window['timestamp_from'].min())
print("End:", reference_window['timestamp_from'].max())
print("\nDetection Window (Window 14) Time Span:")
print("Start:", detection_window['timestamp_from'].min())
print("End:", detection_window['timestamp_from'].max())
# Out:
# Reference Window (Window 0) Time Span:
# Start: 2017-01-09 09:49:50+00:00
# End: 2018-01-25 17:31:07+00:00
#
# Detection Window (Window 14) Time Span:
# Start: 2018-01-19 15:46:40+00:00
# End: 2018-07-10 14:32:55+00:00

# %% [markdown]
# ## Step 6b - Setting Characterization Task

# %%
# Setting Characterization Task
TMPD_instance.set_characterization_task(llm_company = "google", llm_model="gemini-2.5-pro", api_key_path='Temp/google_api_key.txt', llm_instructions_path='Codes/LLM_Instructions/instructions_general_approach.yaml')

# Executing Characterization Task
TMPD_instance.run_characterization_task()

# Showing Characterization Task Results
characterization_prompt, characterization_response = TMPD_instance.get_characterization_task()

# %%
print(characterization_prompt)
# Out:
# # MAIN INSTRUCTIONS
#
# ## 1. Role and Goal
#
# - **Role**: You are an expert process mining analyst specializing in concept drift characterization.
# - **Goal**: Your objective is to deeply understand and explain the transformation observed between two versions of a business process. Your primary value is not in listing raw changes, but in synthesizing them into a coherent narrative that explains the *nature*, *scope*, and *impact* of the process evolution.
#
# ## 2. Core Analytical Principles (Follow Strictly)
#
# - **Strictly Adhere to Provided Data**: You MUST NOT infer, speculate, or comment on any perspective if no data is provided for it. If a perspective has no significant changes, state: "**No significant changes were detected for this perspective.**"
# - **Analyze from the Detection Window's Perspective**: Your entire analysis must be based on the process structure as defined in the **Detection Window (the new reality)**. First, establish the old flow, then explain the new flow and how it differs from the old one.
# - **Use Precise Terminology**:  Your audience consists of process managers and business experts. Use precise process mining terms (e.g., "parallel (AND)", "conditional (XOR)") and basic numerical evidence (e.g., frequencies, probabilities). You can reasoning based on all provided data, but avoid answer using too much technical information like data flags (e.g., 'choice=1', 'parallel=1', etc.) or complex statistics (e.g., p-values, effect sizes).
# - **Synthesize, Don't List**: Your main task is to identify high-level patterns. Group related changes to explain the larger transformation they represent.
#
# ## 3. Analysis Workflow & Output Structure
#
# Your final report must follow these four sections precisely.
#
# ### I. Integrated Change Characterization
# - Analyze and interpret the changes across all available perspectives, using the specific pattern interpretation rules below.
#
# #### Control-Flow Perspective
# - Explain the most significant structural transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Reconstruct Local Flows First: For any area with significant changes (a "hotspot"), you MUST first explicitly state the local flow sequence (e.g. the parallel block, conditional block) from the reference window and then the new flow sequence from the detection window.
#     - Characterize the Transformation: Use the flow comparison to synthesize the primary change. Explain the pattern you observe, specially focusing on:
#         - Activity Addition/Deletion: If an activity was completely added or removed from the process, describe its role and how it affects the overall flow.
#         - Activity Repositioning: An activity is repositioned if its place in the overall sequence changes. This often involves it being removed from its old location and re-inserted elsewhere in the flow with new predecessors/successors. Show all important repositions. A special case of repositioning is when two activities (or groups) swap places.
#         - Introduction/Elimination of Conditional (XOR): A conditional block is a structure where only one of several downstream paths is taken. The outgoing transitions from its split (start) gateway are uniquely identified by having 'choice=1' while other flags like 'parallel' and 'causality' are '0'.
#         - Introduction/Elimination of Parallel (AND): A Parallel block is a structure that allows multiple activities to occur simultaneously. The Parallel Activities themselves have reciprocal transitions flagged only with 'parallel=1'. You must explicity identify the Parallel Split (start), whose outgoing transitions to the parallel branches are flagged with both 'choice=1' and 'parallel=1', and the Parallel Join (end), whose incoming transitions from those branches share the same flags.
#         - Introduction/Elimination of a Bypass: A bypass should only be described if a new path allows one or more activities to be skipped entirely (i.e., made optional or removed from a path, not just moved).
#         - Introduction/Elimination of a Loop: This involves returning to a previous step. A transition is part of a loop block if it has 'loop=1'. This can occur alongside 'choice=1' or 'causality=1'.
#
# #### Time Perspective
# - Explain the most significant time transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Explain how timing changed: are there new bottlenecks (delays) or accelerations? Is there more or less variation in processing times?
#     - Ground every claim in numerical evidence from the data sources.
#     - Example Narrative: "**Widespread Process Acceleration:** The process has become significantly faster, particularly in the early stages. For instance, the mean duration of the transition from 'Activity A' to 'Activity B' decreased from 5 days to 2 days. This pattern of acceleration is also observed for transitions 'Activity B' -> 'Activity C' and 'Activity B' -> 'Activity D', suggesting a systemic improvement rather than an isolated one."
#
# #### Resource Perspective
# - Explain the most significant resource transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Highlight shifts in how work is allocated.
#     - Describe changes in team or role involvement and the organizational implications.
#     - **Important Clarification:** When categorical encodings are shown in the format `Role_X->Role_Y`, this does **not** represent a change from Role_X to Role_Y. Instead, it represents the pair of roles assigned to the two activities connected by the transition: `Role_X` for the source activity and `Role_Y` for the target activity. Therefore, a deleted pair means that one of the activities had its role changed, not that Role_X was "replaced" by Role_Y.
#     - Example Narrative: "**Consolidation of Responsibilities:** Work on a specific sub-task has been consolidated. Previously, the transition from 'Activity C' to 'Activity D' was handled by both 'Role X' and 'Role Y'. Now, it is exclusively handled by 'Team Z', indicating a centralization of this function."
#
# #### Data Perspective
# - Explain the most significant data transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Interpret changes in data attribute values between activities.
#     - Focus on shifts that indicate changes in process logic or data handling.
#     - **Important Clarification:** For categorical encodings in the format `Value_X->Value_Y`, interpret this as the combination of attribute values across the two connected activities (Value_X for the source activity, Value_Y for the target). A new or deleted pair reflects that the attribute of one of the activities changed.
#     - Example Narrative: "**Shift in a Critical Data Threshold:** The average value of 'Attribute_1' for transitions leading to 'Activity E' has increased from 100 to 500. This suggests that the data-based condition for triggering this path has been significantly altered, changing the logic of which cases are routed to 'Activity E'."
#
# #### Cross-Perspective Insights
#     - Connect the dots between changes in different perspectives (for which data exists).
#     - Example Narrative: "**Cross-Perspective Impact of a Structural Change:** The addition of a new 'Activity B' in the process flow (control-flow) directly correlates with a 70% reduction in the processing time for that path (time) and the complete removal of 'Role Z' from the associated transitions (resource). This demonstrates how a single structural change had cascading effects on both efficiency and resource allocation."
#
# ### II. Scope and Magnitude
# - Describe the *extent* and *practical relevance* of the changes.
# - Were they localized to one sub-process, or were they widespread?
# - Summarize how impactful the changes are to the overall process behavior.
#
# ### III. Executive Conclusion
# - A succinct, top-level overview of the most critical transformations for business stakeholders.
# - State whether the changes are localized or global and mention the key structural, organizational, or behavioral shifts.
# - Highlight key cross-perspective effects when possible.
#
# # Data Sources
#
#
# ## Reference Transition Matrix
#                            activity_from                              activity_to  frequency  percentual  causality  parallel  choice  loop
#     Declaration_APPROVED_by_PRE_APPROVER Declaration_FINAL_APPROVED_by_SUPERVISOR         95      0.0475          1         0       0     1
# Declaration_FINAL_APPROVED_by_SUPERVISOR          Declaration_REJECTED_by_MISSING         19      0.0095          0         0       1     1
# Declaration_FINAL_APPROVED_by_SUPERVISOR                          Request_Payment        350      0.1750          0         0       1     0
#         Declaration_REJECTED_by_EMPLOYEE        Declaration_SUBMITTED_by_EMPLOYEE         25      0.0125          1         0       0     1
#          Declaration_REJECTED_by_MISSING        Declaration_SUBMITTED_by_EMPLOYEE         14      0.0070          1         0       0     1
#     Declaration_REJECTED_by_PRE_APPROVER         Declaration_REJECTED_by_EMPLOYEE         15      0.0075          1         0       0     1
#       Declaration_REJECTED_by_SUPERVISOR         Declaration_REJECTED_by_EMPLOYEE         11      0.0055          1         0       0     1
#        Declaration_SUBMITTED_by_EMPLOYEE     Declaration_APPROVED_by_PRE_APPROVER         95      0.0475          0         0       1     1
#        Declaration_SUBMITTED_by_EMPLOYEE Declaration_FINAL_APPROVED_by_SUPERVISOR        273      0.1365          0         0       1     1
#        Declaration_SUBMITTED_by_EMPLOYEE     Declaration_REJECTED_by_PRE_APPROVER         16      0.0080          0         0       1     1
#        Declaration_SUBMITTED_by_EMPLOYEE       Declaration_REJECTED_by_SUPERVISOR         11      0.0055          0         0       1     1
#                          Payment_Handled                                      END        349      0.1745          1         0       0     0
#                          Request_Payment                          Payment_Handled        350      0.1750          1         0       0     0
#                                    START        Declaration_SUBMITTED_by_EMPLOYEE        357      0.1785          1         0       0     0
#
# ## Detection Transition Matrix
#                            activity_from                              activity_to  frequency  percentual  causality  parallel  choice  loop
#   Declaration_APPROVED_by_ADMINISTRATION     Declaration_APPROVED_by_BUDGET_OWNER        120      0.0600          0         0       1     0
#   Declaration_APPROVED_by_ADMINISTRATION Declaration_FINAL_APPROVED_by_SUPERVISOR        175      0.0875          0         0       1     0
#     Declaration_APPROVED_by_BUDGET_OWNER Declaration_FINAL_APPROVED_by_SUPERVISOR        117      0.0585          1         0       0     0
# Declaration_FINAL_APPROVED_by_SUPERVISOR                          Request_Payment        292      0.1460          1         0       0     0
#   Declaration_REJECTED_by_ADMINISTRATION         Declaration_REJECTED_by_EMPLOYEE         24      0.0120          1         0       0     1
#         Declaration_REJECTED_by_EMPLOYEE        Declaration_SUBMITTED_by_EMPLOYEE         32      0.0160          1         0       0     1
#        Declaration_SUBMITTED_by_EMPLOYEE   Declaration_APPROVED_by_ADMINISTRATION        304      0.1520          0         0       1     0
#        Declaration_SUBMITTED_by_EMPLOYEE   Declaration_REJECTED_by_ADMINISTRATION         24      0.0120          0         0       1     1
#                          Payment_Handled                                      END        291      0.1455          1         0       0     0
#                          Request_Payment                          Payment_Handled        292      0.1460          1         0       0     0
#                                    START        Declaration_SUBMITTED_by_EMPLOYEE        295      0.1475          1         0       0     0
#
# ## Significant Transition Changes Analysis
# Detailed statistical analysis of 160 significant changes:
#                                                                         transition                                                            feature  perspective      transition_status                                                                   activity_status  p_value  effect_size  ref_value  det_value   dif_value
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                               numerical_std_Amount         data                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   161.0560    161.0560
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                             choice control_flow                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                 time_avg_timestamp         time                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  3126.0833   3126.0833
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                    categorical_unique_BudgetNumber         data                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                 time_std_timestamp         time                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  4443.2207   4443.2207
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER     resource                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   120.0000    120.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                               numerical_avg_Amount         data                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   101.7112    101.7112
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   120.0000    120.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                          frequency control_flow                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   120.0000    120.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                        probability control_flow                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     0.4068      0.4068
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_std_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   124.5736    124.5736
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                             choice control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_avg_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  3116.9659   3116.9659
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                    categorical_unique_BudgetNumber         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_std_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4223.2603   4223.2603
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_avg_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    80.8178     80.8178
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   175.0000    175.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          frequency control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   175.0000    175.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)     categorical_encoding_frequency_role_ADMINISTRATION->SUPERVISOR     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   175.0000    175.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                        probability control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     0.5932      0.5932
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          causality control_flow                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)       categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR     resource                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   117.0000    117.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_std_Amount         data                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   161.1439    161.1439
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_avg_timestamp         time                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  4101.8400   4101.8400
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                    categorical_unique_BudgetNumber         data                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_std_timestamp         time                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  3763.9124   3763.9124
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_avg_Amount         data                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000    99.2849     99.2849
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   117.0000    117.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          frequency control_flow                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   117.0000    117.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                        probability control_flow                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          causality control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_std_Amount         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    86.3522     0.0000    -86.3522
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                               loop control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_avg_timestamp         time                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000  2534.8918     0.0000  -2534.8918
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                    categorical_unique_BudgetNumber         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_std_timestamp         time                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000  3229.9091     0.0000  -3229.9091
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_avg_Amount         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    68.5442     0.0000    -68.5442
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)       categorical_encoding_frequency_role_PRE_APPROVER->SUPERVISOR     resource                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          frequency control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                        probability control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                               numerical_std_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000   100.4905     0.0000   -100.4905
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                               loop control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                             choice control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                 time_avg_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 25020.5263     0.0000 -25020.5263
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                    categorical_unique_BudgetNumber         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                 time_std_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 96273.6389     0.0000 -96273.6389
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)            categorical_encoding_frequency_role_SUPERVISOR->MISSING     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    19.0000     0.0000    -19.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                               numerical_avg_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    64.6080     0.0000    -64.6080
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    19.0000     0.0000    -19.0000
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                          causality control_flow                    new                                                                         no change   0.0000       1.0000     0.0000     1.0000      1.0000
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                               numerical_std_Amount         data significant difference                                                                         no change   0.0000       0.5537   104.6040   140.4015     35.7974
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                             choice control_flow                deleted                                                                         no change   0.0000       1.0000     1.0000     0.0000     -1.0000
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                 time_avg_timestamp         time significant difference                                                                         no change   0.0001      -0.2986  4888.7406  3319.5731  -1569.1676
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                        probability control_flow significant difference                                                                         no change   0.0001      -0.4578     0.9485     1.0000      0.0515
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                          causality control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_std_Amount         data                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   122.9236    122.9236
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                               loop control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4689.1528   4689.1528
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                 time_std_timestamp         time                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4309.9666   4309.9666
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)       categorical_encoding_frequency_role_ADMINISTRATION->EMPLOYEE     resource                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    24.0000     24.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   107.2074    107.2074
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    24.0000     24.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                          frequency control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    24.0000     24.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                        probability control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                          causality control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                               numerical_std_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000   108.6438     0.0000   -108.6438
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                               loop control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 21756.0845     0.0000 -21756.0845
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                 time_std_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 51502.8523     0.0000 -51502.8523
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    87.6822     0.0000    -87.6822
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    14.0000     0.0000    -14.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                        probability control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)              categorical_encoding_frequency_role_MISSING->EMPLOYEE     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    14.0000     0.0000    -14.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                          causality control_flow                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_std_Amount         data                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000   116.0101     0.0000   -116.0101
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                               loop control_flow                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000  1533.4522     0.0000  -1533.4522
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)         categorical_encoding_frequency_role_PRE_APPROVER->EMPLOYEE     resource                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000    15.0000     0.0000    -15.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000   127.3832     0.0000   -127.3832
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000    15.0000     0.0000    -15.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                        probability control_flow                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                          causality control_flow                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)           categorical_encoding_frequency_role_SUPERVISOR->EMPLOYEE     resource                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000    11.0000     0.0000    -11.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_std_Amount         data                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000   159.7203     0.0000   -159.7203
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                               loop control_flow                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000  5109.3591     0.0000  -5109.3591
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                 time_std_timestamp         time                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000  5567.1368     0.0000  -5567.1368
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000   121.3915     0.0000   -121.3915
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000    11.0000     0.0000    -11.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                        probability control_flow                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                               numerical_std_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   141.6388    141.6388
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                             choice control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                 time_avg_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4511.7662   4511.7662
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                    categorical_unique_BudgetNumber         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                 time_std_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000 22912.1205  22912.1205
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)       categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   304.0000    304.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                               numerical_avg_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    90.9769     90.9769
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   304.0000    304.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                          frequency control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   304.0000    304.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                        probability control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     0.9268      0.9268
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)                                               numerical_std_Amount         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    86.3522     0.0000    -86.3522
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)                                                               loop control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)                                                             choice control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)         categorical_encoding_frequency_role_EMPLOYEE->PRE_APPROVER     resource                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
# ...
# Transitions with variations in categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR: [('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_SUPERVISOR->EMPLOYEE: [('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE')]
# Transitions with variations in numerical_std_Amount: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Payment_Handled', 'END'), ('Request_Payment', 'Payment_Handled'), ('START', 'Declaration_SUBMITTED_by_EMPLOYEE')]
# Transitions with variations in loop: [('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in choice: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_EMPLOYEE->PRE_APPROVER: [('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER')]
# Transitions with variations in time_avg_timestamp: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Request_Payment', 'Payment_Handled')]
# Transitions with variations in categorical_unique_BudgetNumber: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in time_std_timestamp: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Request_Payment', 'Payment_Handled')]
# Transitions with variations in categorical_encoding_frequency_role_PRE_APPROVER->EMPLOYEE: [('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE')]
# Transitions with variations in categorical_encoding_frequency_role_SUPERVISOR->MISSING: [('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING')]
# Transitions with variations in categorical_encoding_frequency_role_ADMINISTRATION->EMPLOYEE: [('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE')]
# Transitions with variations in categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER')]
# Transitions with variations in categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION: [('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION')]
# Transitions with variations in numerical_avg_Amount: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_PRE_APPROVER->SUPERVISOR: [('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in frequency: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION')]
# Transitions with variations in categorical_encoding_frequency_role_ADMINISTRATION->SUPERVISOR: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in probability: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_EMPLOYEE->SUPERVISOR: [('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_MISSING->EMPLOYEE: [('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE')]
# New transitions added to the process: [('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Deleted transitions from the process: [('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE')]
# New activities added to the process: ['Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER']
# Deleted activities from the process: ['Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_REJECTED_by_MISSING', 'Declaration_REJECTED_by_SUPERVISOR']
#
# # FINAL INSTRUCTIONS
#
# ALWAYS FOLLOWS THE MAIN INSTRUCTIONS

# %%
print(characterization_response)
# Out:
# Here is the expert analysis of the process transformation.
#
# ### I. Integrated Change Characterization
#
# The analysis reveals a fundamental re-engineering of the declaration approval process, shifting from a complex, multi-channel review to a more structured, sequential workflow. This transformation is evident across all analytical perspectives.
#
# #### Control-Flow Perspective
#
# The core logic of the approval and rejection sub-process has been completely redesigned. The changes indicate a move towards centralization and simplification.
#
# *   **Elimination of a Multi-Path Approval and Introduction of a Staged Approval Workflow:**
#     *   **Reference Flow (Old):** After a declaration was submitted (`Declaration_SUBMITTED_by_EMPLOYEE`), the process entered a complex conditional block with four possible outcomes: direct approval by a `PRE_APPROVER`, direct final approval by a `SUPERVISOR` (bypassing the pre-approver), rejection by a `PRE_APPROVER`, or rejection by a `SUPERVISOR`. This structure allowed for multiple, potentially overlapping, approval and rejection authorities early in the process.
#     *   **Detection Flow (New):** The process has been streamlined significantly. After submission, there is now a single, mandatory gateway activity: `Declaration_APPROVED_by_ADMINISTRATION`. All submitted declarations are first routed to this central point. The previous roles of `PRE_APPROVER` and the initial `SUPERVISOR` review have been entirely removed and replaced by this new structure.
#     *   **Transformation Characterization:** This represents a major **Activity Replacement and Process Simplification**. The ambiguous, multi-path review system has been replaced by a clear, sequential approval workflow initiated by the `ADMINISTRATION` activity.
#
# *   **Introduction of a New Conditional Approval Stage:**
#     *   **Reference Flow (Old):** The primary approval path was a simple sequence: `Declaration_APPROVED_by_PRE_APPROVER` -> `Declaration_FINAL_APPROVED_by_SUPERVISOR`.
#     *   **Detection Flow (New):** A new conditional (XOR) block has been introduced after the initial `ADMINISTRATION` approval. From `Declaration_APPROVED_by_ADMINISTRATION`, cases are routed down one of two paths:
#         1.  Directly to `Declaration_FINAL_APPROVED_by_SUPERVISOR` (occurs in 59% of cases).
#         2.  Sequentially through `Declaration_APPROVED_by_BUDGET_OWNER` before proceeding to `Declaration_FINAL_APPROVED_by_SUPERVISOR` (occurs in 41% of cases).
#     *   **Transformation Characterization:** This change introduces a new, data-driven secondary approval step. The involvement of a `BUDGET_OWNER` is now a formal, conditional part of the process, suggesting that certain declarations (perhaps based on amount or type) require an additional layer of financial scrutiny that did not formally exist before.
#
# *   **Consolidation of Rejection Logic:**
#     *   **Reference Flow (Old):** Rejections could occur at multiple points and for various reasons, involving `PRE_APPROVER`, `SUPERVISOR`, and even a `MISSING` data state.
#     *   **Detection Flow (New):** The rejection logic has been simplified and consolidated. The primary point of rejection now occurs immediately after submission, where `ADMINISTRATION` can reject the declaration (`Declaration_REJECTED_by_ADMINISTRATION`). This single rejection path replaces the three distinct rejection paths that existed previously.
#
# #### Time Perspective
#
# The process redesign appears to have had a positive impact on the efficiency and predictability of the downstream payment activities.
#
# *   **Acceleration in the Payment Sub-Process:** The final stages of the process are now significantly faster. The mean duration for the transition from `Request_Payment` to `Payment_Handled` has decreased from approximately 6,515 to 4,726 time units. A similar acceleration is seen in the transition from `Declaration_FINAL_APPROVED_by_SUPERVISOR` to `Request_Payment`, which shortened from 4,889 to 3,320 time units.
# *   **Increased Process Predictability:** The variability in processing time for the payment stage has been drastically reduced. The standard deviation for the transition `Request_Payment` -> `Payment_Handled` fell from 6,281 to 1,614 time units. This indicates that the payment handling is now not only faster but also much more consistent.
#
# #### Resource Perspective
#
# The process transformation is underpinned by a significant organizational restructuring, with roles being eliminated, created, and redefined.
#
# *   **Elimination of Roles and Consolidation of Responsibilities:** The `PRE_APPROVER` role has been completely removed from the process. Its responsibilities for initial review have been absorbed and formalized by the new `ADMINISTRATION` role. Furthermore, the `MISSING` role, associated with a now-obsolete rejection path, has also been eliminated.
# *   **Introduction of New Specialist Roles:** Two new roles, `ADMINISTRATION` and `BUDGET OWNER`, have been introduced to manage the redesigned approval workflow. `ADMINISTRATION` now serves as the central gatekeeper for all incoming declarations, while the `BUDGET OWNER` is involved conditionally, likely for declarations requiring specific financial oversight. This indicates a shift towards a more specialized and formalized division of labor in the approval process.
#
# #### Data Perspective
#
# Changes in data handling reflect the new process logic and suggest the process is now handling a different profile of cases.
#
# *   **Increased Variance in Declaration Amounts:** Across several key process steps, including submission and payment, the standard deviation of the `Amount` attribute has increased significantly (e.g., from 104 to 140 for the transition from `START` to `Declaration_SUBMITTED_by_EMPLOYEE`). This indicates that the process is now handling declarations with a wider and more variable range of monetary values than before.
#
# #### Cross-Perspective Insights
#
# The observed changes are highly interconnected, demonstrating how a single strategic decision to restructure the process had cascading effects.
#
# *   **Structural Redesign Drives Efficiency Gains:** The control-flow change—replacing the multi-path `PRE_APPROVER`/`SUPERVISOR` review with a streamlined `ADMINISTRATION`/`BUDGET OWNER` workflow—is the primary driver of the observed transformation. This organizational change (Resource) directly led to a more structured process. This new structure, in turn, appears to produce more consistent and clear-cut outputs, enabling the downstream payment activities to become significantly faster and more predictable (Time).
#
# ### II. Scope and Magnitude
#
# *   **Scope:** The changes are **widespread and systemic**, not localized. While the very beginning (submission) and end (payment) of the process remain conceptually similar, the entire core logic—the approval and rejection sub-process—has been fundamentally re-engineered. This constitutes a global change to the process's operational model.
# *   **Magnitude:** The magnitude of the drift is **high**. This was not an incremental improvement but a complete overhaul. The elimination and creation of multiple activities and roles, the simplification of complex conditional logic, and the introduction of a new staged approval workflow represent a major transformation of the process's behavior, logic, and organizational structure.
#
# ### III. Executive Conclusion
#
# The business process for handling declarations has undergone a **major and systemic re-engineering of its core approval workflow**. The previous, complex approval model involving `PRE_APPROVER` and `SUPERVISOR` roles has been entirely replaced by a more streamlined, two-stage system managed by newly introduced `ADMINISTRATION` and `BUDGET OWNER` roles.
#
# This strategic overhaul has centralized the initial review and simplified rejection handling into a single, clear path. A key outcome of this structural and organizational transformation is a significant improvement in downstream efficiency: the final payment stages are now notably **faster and more predictable**. The changes are global in scope and have fundamentally altered how declarations are reviewed and approved.

# %%
# Setting Characterization Task
TMPD_instance.set_characterization_task(llm_company = "openai", llm_model="gpt-5", api_key_path='Temp/openai_api_key.txt', llm_instructions_path='Codes/LLM_Instructions/instructions_general_approach.yaml') 

# Executing Characterization Task
TMPD_instance.run_characterization_task()

# Showing Characterization Task Results
characterization_prompt, characterization_response = TMPD_instance.get_characterization_task()

# %%
print(characterization_prompt)
# Out:
# # MAIN INSTRUCTIONS
#
# ## 1. Role and Goal
#
# - **Role**: You are an expert process mining analyst specializing in concept drift characterization.
# - **Goal**: Your objective is to deeply understand and explain the transformation observed between two versions of a business process. Your primary value is not in listing raw changes, but in synthesizing them into a coherent narrative that explains the *nature*, *scope*, and *impact* of the process evolution.
#
# ## 2. Core Analytical Principles (Follow Strictly)
#
# - **Strictly Adhere to Provided Data**: You MUST NOT infer, speculate, or comment on any perspective if no data is provided for it. If a perspective has no significant changes, state: "**No significant changes were detected for this perspective.**"
# - **Analyze from the Detection Window's Perspective**: Your entire analysis must be based on the process structure as defined in the **Detection Window (the new reality)**. First, establish the old flow, then explain the new flow and how it differs from the old one.
# - **Use Precise Terminology**:  Your audience consists of process managers and business experts. Use precise process mining terms (e.g., "parallel (AND)", "conditional (XOR)") and basic numerical evidence (e.g., frequencies, probabilities). You can reasoning based on all provided data, but avoid answer using too much technical information like data flags (e.g., 'choice=1', 'parallel=1', etc.) or complex statistics (e.g., p-values, effect sizes).
# - **Synthesize, Don't List**: Your main task is to identify high-level patterns. Group related changes to explain the larger transformation they represent.
#
# ## 3. Analysis Workflow & Output Structure
#
# Your final report must follow these four sections precisely.
#
# ### I. Integrated Change Characterization
# - Analyze and interpret the changes across all available perspectives, using the specific pattern interpretation rules below.
#
# #### Control-Flow Perspective
# - Explain the most significant structural transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Reconstruct Local Flows First: For any area with significant changes (a "hotspot"), you MUST first explicitly state the local flow sequence (e.g. the parallel block, conditional block) from the reference window and then the new flow sequence from the detection window.
#     - Characterize the Transformation: Use the flow comparison to synthesize the primary change. Explain the pattern you observe, specially focusing on:
#         - Activity Addition/Deletion: If an activity was completely added or removed from the process, describe its role and how it affects the overall flow.
#         - Activity Repositioning: An activity is repositioned if its place in the overall sequence changes. This often involves it being removed from its old location and re-inserted elsewhere in the flow with new predecessors/successors. Show all important repositions. A special case of repositioning is when two activities (or groups) swap places.
#         - Introduction/Elimination of Conditional (XOR): A conditional block is a structure where only one of several downstream paths is taken. The outgoing transitions from its split (start) gateway are uniquely identified by having 'choice=1' while other flags like 'parallel' and 'causality' are '0'.
#         - Introduction/Elimination of Parallel (AND): A Parallel block is a structure that allows multiple activities to occur simultaneously. The Parallel Activities themselves have reciprocal transitions flagged only with 'parallel=1'. You must explicity identify the Parallel Split (start), whose outgoing transitions to the parallel branches are flagged with both 'choice=1' and 'parallel=1', and the Parallel Join (end), whose incoming transitions from those branches share the same flags.
#         - Introduction/Elimination of a Bypass: A bypass should only be described if a new path allows one or more activities to be skipped entirely (i.e., made optional or removed from a path, not just moved).
#         - Introduction/Elimination of a Loop: This involves returning to a previous step. A transition is part of a loop block if it has 'loop=1'. This can occur alongside 'choice=1' or 'causality=1'.
#
# #### Time Perspective
# - Explain the most significant time transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Explain how timing changed: are there new bottlenecks (delays) or accelerations? Is there more or less variation in processing times?
#     - Ground every claim in numerical evidence from the data sources.
#     - Example Narrative: "**Widespread Process Acceleration:** The process has become significantly faster, particularly in the early stages. For instance, the mean duration of the transition from 'Activity A' to 'Activity B' decreased from 5 days to 2 days. This pattern of acceleration is also observed for transitions 'Activity B' -> 'Activity C' and 'Activity B' -> 'Activity D', suggesting a systemic improvement rather than an isolated one."
#
# #### Resource Perspective
# - Explain the most significant resource transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Highlight shifts in how work is allocated.
#     - Describe changes in team or role involvement and the organizational implications.
#     - **Important Clarification:** When categorical encodings are shown in the format `Role_X->Role_Y`, this does **not** represent a change from Role_X to Role_Y. Instead, it represents the pair of roles assigned to the two activities connected by the transition: `Role_X` for the source activity and `Role_Y` for the target activity. Therefore, a deleted pair means that one of the activities had its role changed, not that Role_X was "replaced" by Role_Y.
#     - Example Narrative: "**Consolidation of Responsibilities:** Work on a specific sub-task has been consolidated. Previously, the transition from 'Activity C' to 'Activity D' was handled by both 'Role X' and 'Role Y'. Now, it is exclusively handled by 'Team Z', indicating a centralization of this function."
#
# #### Data Perspective
# - Explain the most significant data transformations by identifying high-level patterns. Your analysis must focus on the transformation between the old and new process logic.
#     - Interpret changes in data attribute values between activities.
#     - Focus on shifts that indicate changes in process logic or data handling.
#     - **Important Clarification:** For categorical encodings in the format `Value_X->Value_Y`, interpret this as the combination of attribute values across the two connected activities (Value_X for the source activity, Value_Y for the target). A new or deleted pair reflects that the attribute of one of the activities changed.
#     - Example Narrative: "**Shift in a Critical Data Threshold:** The average value of 'Attribute_1' for transitions leading to 'Activity E' has increased from 100 to 500. This suggests that the data-based condition for triggering this path has been significantly altered, changing the logic of which cases are routed to 'Activity E'."
#
# #### Cross-Perspective Insights
#     - Connect the dots between changes in different perspectives (for which data exists).
#     - Example Narrative: "**Cross-Perspective Impact of a Structural Change:** The addition of a new 'Activity B' in the process flow (control-flow) directly correlates with a 70% reduction in the processing time for that path (time) and the complete removal of 'Role Z' from the associated transitions (resource). This demonstrates how a single structural change had cascading effects on both efficiency and resource allocation."
#
# ### II. Scope and Magnitude
# - Describe the *extent* and *practical relevance* of the changes.
# - Were they localized to one sub-process, or were they widespread?
# - Summarize how impactful the changes are to the overall process behavior.
#
# ### III. Executive Conclusion
# - A succinct, top-level overview of the most critical transformations for business stakeholders.
# - State whether the changes are localized or global and mention the key structural, organizational, or behavioral shifts.
# - Highlight key cross-perspective effects when possible.
#
# # Data Sources
#
#
# ## Reference Transition Matrix
#                            activity_from                              activity_to  frequency  percentual  causality  parallel  choice  loop
#     Declaration_APPROVED_by_PRE_APPROVER Declaration_FINAL_APPROVED_by_SUPERVISOR         95      0.0475          1         0       0     1
# Declaration_FINAL_APPROVED_by_SUPERVISOR          Declaration_REJECTED_by_MISSING         19      0.0095          0         0       1     1
# Declaration_FINAL_APPROVED_by_SUPERVISOR                          Request_Payment        350      0.1750          0         0       1     0
#         Declaration_REJECTED_by_EMPLOYEE        Declaration_SUBMITTED_by_EMPLOYEE         25      0.0125          1         0       0     1
#          Declaration_REJECTED_by_MISSING        Declaration_SUBMITTED_by_EMPLOYEE         14      0.0070          1         0       0     1
#     Declaration_REJECTED_by_PRE_APPROVER         Declaration_REJECTED_by_EMPLOYEE         15      0.0075          1         0       0     1
#       Declaration_REJECTED_by_SUPERVISOR         Declaration_REJECTED_by_EMPLOYEE         11      0.0055          1         0       0     1
#        Declaration_SUBMITTED_by_EMPLOYEE     Declaration_APPROVED_by_PRE_APPROVER         95      0.0475          0         0       1     1
#        Declaration_SUBMITTED_by_EMPLOYEE Declaration_FINAL_APPROVED_by_SUPERVISOR        273      0.1365          0         0       1     1
#        Declaration_SUBMITTED_by_EMPLOYEE     Declaration_REJECTED_by_PRE_APPROVER         16      0.0080          0         0       1     1
#        Declaration_SUBMITTED_by_EMPLOYEE       Declaration_REJECTED_by_SUPERVISOR         11      0.0055          0         0       1     1
#                          Payment_Handled                                      END        349      0.1745          1         0       0     0
#                          Request_Payment                          Payment_Handled        350      0.1750          1         0       0     0
#                                    START        Declaration_SUBMITTED_by_EMPLOYEE        357      0.1785          1         0       0     0
#
# ## Detection Transition Matrix
#                            activity_from                              activity_to  frequency  percentual  causality  parallel  choice  loop
#   Declaration_APPROVED_by_ADMINISTRATION     Declaration_APPROVED_by_BUDGET_OWNER        120      0.0600          0         0       1     0
#   Declaration_APPROVED_by_ADMINISTRATION Declaration_FINAL_APPROVED_by_SUPERVISOR        175      0.0875          0         0       1     0
#     Declaration_APPROVED_by_BUDGET_OWNER Declaration_FINAL_APPROVED_by_SUPERVISOR        117      0.0585          1         0       0     0
# Declaration_FINAL_APPROVED_by_SUPERVISOR                          Request_Payment        292      0.1460          1         0       0     0
#   Declaration_REJECTED_by_ADMINISTRATION         Declaration_REJECTED_by_EMPLOYEE         24      0.0120          1         0       0     1
#         Declaration_REJECTED_by_EMPLOYEE        Declaration_SUBMITTED_by_EMPLOYEE         32      0.0160          1         0       0     1
#        Declaration_SUBMITTED_by_EMPLOYEE   Declaration_APPROVED_by_ADMINISTRATION        304      0.1520          0         0       1     0
#        Declaration_SUBMITTED_by_EMPLOYEE   Declaration_REJECTED_by_ADMINISTRATION         24      0.0120          0         0       1     1
#                          Payment_Handled                                      END        291      0.1455          1         0       0     0
#                          Request_Payment                          Payment_Handled        292      0.1460          1         0       0     0
#                                    START        Declaration_SUBMITTED_by_EMPLOYEE        295      0.1475          1         0       0     0
#
# ## Significant Transition Changes Analysis
# Detailed statistical analysis of 160 significant changes:
#                                                                         transition                                                            feature  perspective      transition_status                                                                   activity_status  p_value  effect_size  ref_value  det_value   dif_value
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                               numerical_std_Amount         data                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   161.0560    161.0560
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                             choice control_flow                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                 time_avg_timestamp         time                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  3126.0833   3126.0833
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                    categorical_unique_BudgetNumber         data                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                 time_std_timestamp         time                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  4443.2207   4443.2207
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER     resource                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   120.0000    120.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                               numerical_avg_Amount         data                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   101.7112    101.7112
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   120.0000    120.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                          frequency control_flow                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   120.0000    120.0000
#     (Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)                                                        probability control_flow                    new new(Declaration_APPROVED_by_ADMINISTRATION, Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     0.4068      0.4068
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_std_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   124.5736    124.5736
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                             choice control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_avg_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  3116.9659   3116.9659
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                    categorical_unique_BudgetNumber         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_std_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4223.2603   4223.2603
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_avg_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    80.8178     80.8178
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   175.0000    175.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          frequency control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   175.0000    175.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)     categorical_encoding_frequency_role_ADMINISTRATION->SUPERVISOR     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   175.0000    175.0000
# (Declaration_APPROVED_by_ADMINISTRATION, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                        probability control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     0.5932      0.5932
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          causality control_flow                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)       categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR     resource                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   117.0000    117.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_std_Amount         data                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   161.1439    161.1439
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_avg_timestamp         time                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  4101.8400   4101.8400
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                    categorical_unique_BudgetNumber         data                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_std_timestamp         time                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000  3763.9124   3763.9124
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_avg_Amount         data                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000    99.2849     99.2849
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   117.0000    117.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          frequency control_flow                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000   117.0000    117.0000
#   (Declaration_APPROVED_by_BUDGET_OWNER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                        probability control_flow                    new                                         new(Declaration_APPROVED_by_BUDGET_OWNER)   0.0000       1.0000     0.0000     1.0000      1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          causality control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_std_Amount         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    86.3522     0.0000    -86.3522
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                               loop control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_avg_timestamp         time                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000  2534.8918     0.0000  -2534.8918
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                    categorical_unique_BudgetNumber         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                 time_std_timestamp         time                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000  3229.9091     0.0000  -3229.9091
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                               numerical_avg_Amount         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    68.5442     0.0000    -68.5442
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)       categorical_encoding_frequency_role_PRE_APPROVER->SUPERVISOR     resource                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                          frequency control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
#   (Declaration_APPROVED_by_PRE_APPROVER, Declaration_FINAL_APPROVED_by_SUPERVISOR)                                                        probability control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                               numerical_std_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000   100.4905     0.0000   -100.4905
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                               loop control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                             choice control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                 time_avg_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 25020.5263     0.0000 -25020.5263
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                    categorical_unique_BudgetNumber         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                                 time_std_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 96273.6389     0.0000 -96273.6389
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)            categorical_encoding_frequency_role_SUPERVISOR->MISSING     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    19.0000     0.0000    -19.0000
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING)                                               numerical_avg_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    64.6080     0.0000    -64.6080
#        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Declaration_REJECTED_by_MISSING) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    19.0000     0.0000    -19.0000
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                          causality control_flow                    new                                                                         no change   0.0000       1.0000     0.0000     1.0000      1.0000
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                               numerical_std_Amount         data significant difference                                                                         no change   0.0000       0.5537   104.6040   140.4015     35.7974
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                             choice control_flow                deleted                                                                         no change   0.0000       1.0000     1.0000     0.0000     -1.0000
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                 time_avg_timestamp         time significant difference                                                                         no change   0.0001      -0.2986  4888.7406  3319.5731  -1569.1676
#                        (Declaration_FINAL_APPROVED_by_SUPERVISOR, Request_Payment)                                                        probability control_flow significant difference                                                                         no change   0.0001      -0.4578     0.9485     1.0000      0.0515
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                          causality control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_std_Amount         data                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   122.9236    122.9236
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                               loop control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4689.1528   4689.1528
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                 time_std_timestamp         time                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4309.9666   4309.9666
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)       categorical_encoding_frequency_role_ADMINISTRATION->EMPLOYEE     resource                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    24.0000     24.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   107.2074    107.2074
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    24.0000     24.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                          frequency control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    24.0000     24.0000
#         (Declaration_REJECTED_by_ADMINISTRATION, Declaration_REJECTED_by_EMPLOYEE)                                                        probability control_flow                    new                                       new(Declaration_REJECTED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                          causality control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                               numerical_std_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000   108.6438     0.0000   -108.6438
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                               loop control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 21756.0845     0.0000 -21756.0845
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                 time_std_timestamp         time                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000 51502.8523     0.0000 -51502.8523
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    87.6822     0.0000    -87.6822
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    14.0000     0.0000    -14.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)                                                        probability control_flow                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000     1.0000     0.0000     -1.0000
#               (Declaration_REJECTED_by_MISSING, Declaration_SUBMITTED_by_EMPLOYEE)              categorical_encoding_frequency_role_MISSING->EMPLOYEE     resource                deleted                                          deleted(Declaration_REJECTED_by_MISSING)   0.0000       1.0000    14.0000     0.0000    -14.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                          causality control_flow                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_std_Amount         data                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000   116.0101     0.0000   -116.0101
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                               loop control_flow                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000  1533.4522     0.0000  -1533.4522
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)         categorical_encoding_frequency_role_PRE_APPROVER->EMPLOYEE     resource                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000    15.0000     0.0000    -15.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000   127.3832     0.0000   -127.3832
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000    15.0000     0.0000    -15.0000
#           (Declaration_REJECTED_by_PRE_APPROVER, Declaration_REJECTED_by_EMPLOYEE)                                                        probability control_flow                deleted                                     deleted(Declaration_REJECTED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                          causality control_flow                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)           categorical_encoding_frequency_role_SUPERVISOR->EMPLOYEE     resource                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000    11.0000     0.0000    -11.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_std_Amount         data                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000   159.7203     0.0000   -159.7203
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                               loop control_flow                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                 time_avg_timestamp         time                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000  5109.3591     0.0000  -5109.3591
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                    categorical_unique_BudgetNumber         data                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                 time_std_timestamp         time                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000  5567.1368     0.0000  -5567.1368
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                               numerical_avg_Amount         data                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000   121.3915     0.0000   -121.3915
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000    11.0000     0.0000    -11.0000
#             (Declaration_REJECTED_by_SUPERVISOR, Declaration_REJECTED_by_EMPLOYEE)                                                        probability control_flow                deleted                                       deleted(Declaration_REJECTED_by_SUPERVISOR)   0.0000       1.0000     1.0000     0.0000     -1.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                               numerical_std_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   141.6388    141.6388
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                             choice control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                 time_avg_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000  4511.7662   4511.7662
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                    categorical_unique_BudgetNumber         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     1.0000      1.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                 time_std_timestamp         time                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000 22912.1205  22912.1205
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)       categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   304.0000    304.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                               numerical_avg_Amount         data                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000    90.9769     90.9769
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION) categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER     resource                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   304.0000    304.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                          frequency control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000   304.0000    304.0000
#        (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_ADMINISTRATION)                                                        probability control_flow                    new                                       new(Declaration_APPROVED_by_ADMINISTRATION)   0.0000       1.0000     0.0000     0.9268      0.9268
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)                                               numerical_std_Amount         data                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    86.3522     0.0000    -86.3522
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)                                                               loop control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)                                                             choice control_flow                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000     1.0000     0.0000     -1.0000
#          (Declaration_SUBMITTED_by_EMPLOYEE, Declaration_APPROVED_by_PRE_APPROVER)         categorical_encoding_frequency_role_EMPLOYEE->PRE_APPROVER     resource                deleted                                     deleted(Declaration_APPROVED_by_PRE_APPROVER)   0.0000       1.0000    95.0000     0.0000    -95.0000
# ...
# Transitions with variations in categorical_encoding_frequency_role_BUDGET OWNER->SUPERVISOR: [('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_SUPERVISOR->EMPLOYEE: [('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE')]
# Transitions with variations in numerical_std_Amount: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Payment_Handled', 'END'), ('Request_Payment', 'Payment_Handled'), ('START', 'Declaration_SUBMITTED_by_EMPLOYEE')]
# Transitions with variations in loop: [('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in choice: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_EMPLOYEE->PRE_APPROVER: [('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER')]
# Transitions with variations in time_avg_timestamp: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Request_Payment', 'Payment_Handled')]
# Transitions with variations in categorical_unique_BudgetNumber: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in time_std_timestamp: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Request_Payment', 'Payment_Handled')]
# Transitions with variations in categorical_encoding_frequency_role_PRE_APPROVER->EMPLOYEE: [('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE')]
# Transitions with variations in categorical_encoding_frequency_role_SUPERVISOR->MISSING: [('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING')]
# Transitions with variations in categorical_encoding_frequency_role_ADMINISTRATION->EMPLOYEE: [('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE')]
# Transitions with variations in categorical_encoding_frequency_role_ADMINISTRATION->BUDGET OWNER: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER')]
# Transitions with variations in categorical_encoding_frequency_role_EMPLOYEE->ADMINISTRATION: [('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION')]
# Transitions with variations in numerical_avg_Amount: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_PRE_APPROVER->SUPERVISOR: [('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_resource_STAFF MEMBER->STAFF MEMBER: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in frequency: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION')]
# Transitions with variations in categorical_encoding_frequency_role_ADMINISTRATION->SUPERVISOR: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in probability: [('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Request_Payment'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_EMPLOYEE->SUPERVISOR: [('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR')]
# Transitions with variations in categorical_encoding_frequency_role_MISSING->EMPLOYEE: [('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE')]
# New transitions added to the process: [('Declaration_APPROVED_by_BUDGET_OWNER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_ADMINISTRATION'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_ADMINISTRATION'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER'), ('Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_FINAL_APPROVED_by_SUPERVISOR')]
# Deleted transitions from the process: [('Declaration_FINAL_APPROVED_by_SUPERVISOR', 'Declaration_REJECTED_by_MISSING'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_APPROVED_by_PRE_APPROVER'), ('Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_SUPERVISOR'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_REJECTED_by_PRE_APPROVER'), ('Declaration_REJECTED_by_MISSING', 'Declaration_SUBMITTED_by_EMPLOYEE'), ('Declaration_SUBMITTED_by_EMPLOYEE', 'Declaration_FINAL_APPROVED_by_SUPERVISOR'), ('Declaration_REJECTED_by_SUPERVISOR', 'Declaration_REJECTED_by_EMPLOYEE'), ('Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_REJECTED_by_EMPLOYEE')]
# New activities added to the process: ['Declaration_REJECTED_by_ADMINISTRATION', 'Declaration_APPROVED_by_ADMINISTRATION', 'Declaration_APPROVED_by_BUDGET_OWNER']
# Deleted activities from the process: ['Declaration_REJECTED_by_PRE_APPROVER', 'Declaration_APPROVED_by_PRE_APPROVER', 'Declaration_REJECTED_by_MISSING', 'Declaration_REJECTED_by_SUPERVISOR']
#
# # FINAL INSTRUCTIONS
#
# ALWAYS FOLLOWS THE MAIN INSTRUCTIONS

# %%
print(characterization_response)
# Out:
# I. Integrated Change Characterization
#
# Control-Flow Perspective
#
# Hotspot A: Early approvals (from Submission to approvals)
# - Reference (old) local flow from Submission (XOR):
#   - Path 1: Submission -> Approved_by_PRE_APPROVER -> Final_Approved_by_SUPERVISOR (95 cases)
#   - Path 2: Submission -> Final_Approved_by_SUPERVISOR (273 cases)
#   - Path 3: Submission -> Rejected_by_PRE_APPROVER -> Rejected_by_EMPLOYEE -> Submission (loop)
#   - Path 4: Submission -> Rejected_by_SUPERVISOR -> Rejected_by_EMPLOYEE -> Submission (loop)
# - Detection (new) local flow from Submission (XOR):
#   - Path A: Submission -> Approved_by_ADMINISTRATION -> Final_Approved_by_SUPERVISOR (175 cases; probability 0.593 on the Admin split)
#   - Path B: Submission -> Approved_by_ADMINISTRATION -> Approved_by_BUDGET_OWNER -> Final_Approved_by_SUPERVISOR (120 cases; probability 0.407 on the Admin split)
#   - Path C (rework loop): Submission -> Rejected_by_ADMINISTRATION -> Rejected_by_EMPLOYEE -> Submission (24 cases)
#
# Characterization
# - Activity additions: Approved_by_ADMINISTRATION and Approved_by_BUDGET_OWNER inserted between Submission and Final_Approved_by_SUPERVISOR. The Budget Owner step is optional (XOR): cases either go Admin -> Supervisor (59.3%) or Admin -> Budget Owner -> Supervisor (40.7%).
# - Activity deletions: Approved_by_PRE_APPROVER, Rejected_by_PRE_APPROVER, Rejected_by_SUPERVISOR, and Rejected_by_MISSING removed.
# - Activity repositioning: Final_Approved_by_SUPERVISOR is shifted downstream. Previously it could be reached directly from Submission; now it is only reachable after Admin approval (and optionally Budget Owner). This removes the earlier bypass of a pre-approval step.
# - Loop restructuring: Rework loops now occur only via Admin rejection (Rejected_by_ADMINISTRATION -> Rejected_by_EMPLOYEE -> Submission). Prior loops via Pre-Approver and Supervisor rejections were eliminated.
#
# Hotspot B: Post-final-approval routing
# - Reference (old) local flow from Final_Approved_by_SUPERVISOR (XOR):
#   - Path 1: Final_Approved_by_SUPERVISOR -> Request_Payment (350 cases)
#   - Path 2 (exception loop): Final_Approved_by_SUPERVISOR -> Rejected_by_MISSING -> Submission (19 + 14 cases on the loop-back)
# - Detection (new) local flow:
#   - Deterministic: Final_Approved_by_SUPERVISOR -> Request_Payment (292 cases)
#
# Characterization
# - Elimination of a conditional (XOR) and loop: The post-approval exception branch to Rejected_by_MISSING was removed. The supervisor decision now causally and always leads to Request_Payment (probability increased from 0.9485 to 1.000).
#
# Hotspot C: Payment sub-process
# - Reference and Detection: Request_Payment -> Payment_Handled -> End remained structurally unchanged (350→292; 349→291 cases), with timing changes detailed below.
#
# Parallel (AND) and Bypass
# - Parallel (AND): No significant parallel blocks were detected in either version.
# - Bypass changes: In the old flow, Submission could bypass pre-approval and go directly to the Supervisor. In the new flow, that bypass is eliminated (Admin approval is now required); conversely, the newly added Budget Owner step is optional (XOR), i.e., Admin can bypass Budget Owner for 59.3% of cases.
#
# Time Perspective
#
# - Post-approval and payment acceleration (reduced delay and variability):
#   - Final_Approved_by_SUPERVISOR -> Request_Payment
#     - Mean decreased from 4,888.74 to 3,319.57 (−1,569.17; 32% faster); transition became fully deterministic.
#   - Request_Payment -> Payment_Handled
#     - Mean decreased from 6,514.94 to 4,725.62 (−1,789.32; 27% faster).
#     - Variation dropped markedly: std from 6,281.25 to 1,613.73.
#   - Eliminated slow exception: The removed branch Final_Approved_by_SUPERVISOR -> Rejected_by_MISSING had a very large mean delay (25,020.53), and the loop-back Rejected_by_MISSING -> Submission averaged 21,756.08. Their removal eliminates extreme tail delays.
#
# - Upstream approvals became longer and multi-leg:
#   - New early step: Submission -> Approved_by_ADMINISTRATION averages 4,511.77.
#   - Admin splits:
#     - Admin -> Supervisor averages 3,116.97.
#     - Admin -> Budget Owner averages 3,126.08; Budget Owner -> Supervisor averages 4,101.84.
#   - Relative to the old direct path Submission -> Final_Approved_by_SUPERVISOR (mean 966.46) and Submission -> Approved_by_PRE_APPROVER (mean 2,341.85), the early decision-making has shifted to a longer, staged approval sequence.
#
# Resource Perspective
#
# - Role realignment and consolidation around frontline approvals:
#   - New role involvement:
#     - EMPLOYEE -> ADMINISTRATION on Submission -> Approved_by_ADMINISTRATION (304) and Submission -> Rejected_by_ADMINISTRATION (24).
#     - ADMINISTRATION -> SUPERVISOR (175) and ADMINISTRATION -> BUDGET OWNER (120).
#     - BUDGET OWNER -> SUPERVISOR (117).
#     - ADMINISTRATION -> EMPLOYEE on rejection handling (24).
#   - Removed role pairs indicate decommissioned steps:
#     - EMPLOYEE -> PRE_APPROVER, PRE_APPROVER -> SUPERVISOR, PRE_APPROVER -> EMPLOYEE (deleted).
#     - EMPLOYEE -> SUPERVISOR (direct approval) and SUPERVISOR -> EMPLOYEE (rejection) (deleted).
#     - SUPERVISOR -> MISSING (deleted).
# - Pattern: decision authority is centralized to ADMINISTRATION, with an optional BUDGET OWNER check before SUPERVISOR’s final approval. Responsibilities previously split across PRE_APPROVER and SUPERVISOR rejections have been retired.
#
# Data Perspective
#
# - Amount distribution shifts along key transitions:
#   - Post-approval/payment:
#     - Request_Payment -> Payment_Handled: std Amount increased from 104.60 to 140.40.
#     - Payment_Handled -> End: std Amount increased from 104.75 to 140.53.
#   - New approval branches differentiate by Amount:
#     - Admin -> Supervisor: avg Amount 80.82.
#     - Admin -> Budget Owner: avg Amount 101.71.
#     - Budget Owner -> Supervisor: avg Amount 99.28.
#   - Interpretation: the two Admin outcomes (direct to Supervisor vs via Budget Owner) are associated with different Amount profiles at transition level, suggesting systematic segmentation of cases across the new XOR branches.
# - BudgetNumber presence on new approval transitions is recorded (categorical uniqueness present), but no further pattern is provided.
#
# Cross-Perspective Insights
#
# - Structural centralization (Admin as the mandatory gate and optional Budget Owner step) coincides with:
#   - Resource reallocation to ADMINISTRATION and BUDGET OWNER and the removal of PRE_APPROVER/SUPERVISOR rejection responsibilities.
#   - Data segmentation: the optional Budget Owner branch carries higher average Amount than the direct Admin->Supervisor branch, aligning role involvement with case attributes.
# - Elimination of the post-approval exception XOR (to Rejected_by_MISSING) directly reduced end-to-end delays and variability in the payment stage, and turned the supervisor-to-payment handover into a deterministic, faster path.
#
#
# II. Scope and Magnitude
#
# - Scope: Global. The core approval backbone was reengineered:
#   - Pre-approver and Supervisor rejection activities were removed.
#   - Administration approval was introduced as a mandatory step; Budget Owner approval added as an optional branch.
#   - The post-final-approval exception path was removed, simplifying downstream flow to payment.
# - Magnitude:
#   - Routing probabilities in the new Admin split are material: 59.3% go Admin -> Supervisor and 40.7% go Admin -> Budget Owner -> Supervisor.
#   - Determinism increased at a key handover: Final_Approved_by_SUPERVISOR now always leads to Request_Payment (probability to payment from 0.9485 to 1.000).
#   - Timing impacts are substantial:
#     - Early approvals: longer, multi-leg path (new per-leg means around 3,100–4,500 units).
#     - Downstream: significant acceleration and reduced variability (−1,569 to −1,789 units in two largest transitions; large std reduction).
# - Practical relevance: The process now trades longer, more structured early approvals for faster, predictable fulfillment once approved. Removal of slow exception loops eliminates extreme tail cases, likely improving overall stability and throughput after approval.
#
#
# III. Executive Conclusion
#
# The process underwent a global redesign of its approval logic. A centralized Administration approval is now mandatory, optionally followed by a Budget Owner check, before reaching the Supervisor’s final approval. Legacy pre-approval and supervisor-level rejection steps were removed, and a problematic post-approval exception branch was eliminated. This redesign:
# - Centralizes responsibility to Administration and introduces Budget Owner selectively, replacing Pre-Approver and Supervisor rejection paths.
# - Makes the supervisor-to-payment handoff fully deterministic and substantially faster, while cutting downstream variability.
# - Segments cases across the optional Budget Owner branch with distinct Amount profiles.
#
# Net effect: approvals are more controlled and staged upfront, while the post-approval and payment phases are simpler, faster, and more predictable. The changes are global and materially alter structure, routing probabilities, resource allocation, and timing behavior.

# %% [markdown]
# ## Step 6c - Setting Explanation Task

# %%
# TODO
